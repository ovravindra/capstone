# %%
import pandas as pd
import numpy as np
import nltk
import sklearn
import matplotlib.pyplot as plt
import re
import tqdm
from sklearn import utils

# %matplotlib inline

# %%
twitter_df = pd.read_csv('twitter_train.csv')
twitter_df = twitter_df.fillna('0')

# %%
twitter_df = twitter_df.drop('location', axis=1)
target = twitter_df.target
# twitter_df = twitter_df.drop('target', axis=1)

# %%
# CBOW is a word embedding technique to predict middle word in the context.
# hence capturing some semantic information.

# %%
from nltk import TweetTokenizer
wt = TweetTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_corpus(df_1 = twitter_df, text_col = 'text'):
    
    # refining the text by removing the special characters,
    # lower casing all the words, removing white spaces
    
    df = df_1.copy()
    df.dropna(inplace=True)
    
    url_re = r'(https?:\/\/\S+)$'
    tags = r'@([a-zA-Z0-9:]+)\s' # mentions
    english_re = r'([a-zA-Z]\w+)'
    extended_stop_words_re = stop_words + ['&amp;','rt','th','co', 're','ve','kim','daca','p.m.']
    single_letters_re = r'.'
    
    df['preprocessed_'+ text_col] = df[text_col].str.lower() # lower casing the text.
    
    df['preprocessed_'+ text_col] = df['preprocessed_'+ text_col].apply(lambda row: ' '.join([word for word in row.split()
                                                                                             if (re.match(english_re, word))
                                                                                             and (not word in extended_stop_words_re)
                                                                                             and (not word in single_letters_re)]))
    
    # df['preprocessed_'+text] = re.sub(english, '', df['preprocessed_'+text])
    df['preprocessed_'+ text_col] = df['preprocessed_'+text_col].apply(lambda row: re.sub(url_re, '', row)) # removing urls.
    
    # df['preprocessed_'+ text_col] = df['preprocessed_'+text_col].apply(lambda row: re.sub(tags, '', row)) # removing hash-tags.    
    # doc = doc.strip() # removes both the leading and trailing characters.
    
    # tokenize document
    df['tokenised_' + text_col] = df['preprocessed_'+ text_col].apply(lambda row: wt.tokenize(row))
    # df['tokenised_' + text_col].apply(re.sub(single_letters_re, '', row))
    return df

# %%
norm_df = normalize_corpus(twitter_df)

# %%
norm_df
# Out:
#          id keyword                                               text  \
# 0         1       0  Our Deeds are the Reason of this #earthquake M...
# 1         4       0             Forest fire near La Ronge Sask. Canada
# 2         5       0  All residents asked to 'shelter in place' are ...
# 3         6       0  13,000 people receive #wildfires evacuation or...
# 4         7       0  Just got sent this photo from Ruby #Alaska as ...
# ...     ...     ...                                                ...
# 7608  10869       0  Two giant cranes holding a bridge collapse int...
# 7609  10870       0  @aria_ahrary @TheTawniest The out of control w...
# 7610  10871       0  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611  10872       0  Police investigating after an e-bike collided ...
# 7612  10873       0  The Latest: More Homes Razed by Northern Calif...
#
#       target                                  preprocessed_text  \
# 0          1                  deeds reason may allah forgive us
# 1          1             forest fire near la ronge sask. canada
# 2          1  residents asked place' notified officers. evac...
# 3          1        people receive evacuation orders california
# 4          1             got sent photo ruby smoke pours school
# ...      ...                                                ...
# 7608       1  two giant cranes holding bridge collapse nearb...
# 7609       1  control wild fires california even northern pa...
# 7610       1                    m1.94 utc]?5km volcano hawaii.
# 7611       1  police investigating collided car little portu...
# 7612       1  latest: homes razed northern california wildfi...
#
#                                          tokenised_text
# 0              [deeds, reason, may, allah, forgive, us]
# 1      [forest, fire, near, la, ronge, sask, ., canada]
# 2     [residents, asked, place, ', notified, officer...
# 3     [people, receive, evacuation, orders, california]
# 4        [got, sent, photo, ruby, smoke, pours, school]
# ...                                                 ...
# 7608  [two, giant, cranes, holding, bridge, collapse...
# 7609  [control, wild, fires, california, even, north...
# 7610    [m1, ., 94, utc, ], ?, 5km, volcano, hawaii, .]
# 7611  [police, investigating, collided, car, little,...
# 7612  [latest, :, homes, razed, northern, california...
#
# [7613 rows x 6 columns]

# %%
# importing the requires libraries to generate word embeddings.
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

tokenised_doc = norm_df.tokenised_text
target = norm_df.target

# convert tokenized document into gensim formatted tagged data
tagged_data = [TaggedDocument(d , [i]) for i, d in zip(target, tokenised_doc)]

# tagged_data = [TaggedDocument(d , [i]) for (i, d) in norm_df[["keyword", "tokenised_text"]]]

# %%
# tagged_dada_1 = norm_df.apply(lambda r: TaggedDocument(words=r['tokenised_text'], tags = r['keyword']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-6ebc194ddea0> in <module>
# ----> 1 tagged_dada_1 = norm_df.apply(lambda r: TaggedDocument(words=r['tokenised_text'], tags = r['keyword']))
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-37-6ebc194ddea0> in <lambda>(r)
# ----> 1 tagged_dada_1 = norm_df.apply(lambda r: TaggedDocument(words=r['tokenised_text'], tags = r['keyword']))
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#    4406             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'tokenised_text'

# %%
tagged_data
# Out:
# [TaggedDocument(words=['deeds', 'reason', 'may', 'allah', 'forgive', 'us'], tags=[1]),
#  TaggedDocument(words=['forest', 'fire', 'near', 'la', 'ronge', 'sask', '.', 'canada'], tags=[1]),
#  TaggedDocument(words=['residents', 'asked', 'place', "'", 'notified', 'officers', '.', 'evacuation', 'shelter', 'place', 'orders', 'expected'], tags=[1]),
#  TaggedDocument(words=['people', 'receive', 'evacuation', 'orders', 'california'], tags=[1]),
#  TaggedDocument(words=['got', 'sent', 'photo', 'ruby', 'smoke', 'pours', 'school'], tags=[1]),
#  TaggedDocument(words=['update', 'california', 'hwy', '.', 'closed', 'directions', 'due', 'lake', 'county', 'fire'], tags=[1]),
#  TaggedDocument(words=['heavy', 'rain', 'causes', 'flash', 'flooding', 'streets', 'manitou', ',', 'colorado', 'springs', 'areas'], tags=[1]),
#  TaggedDocument(words=['top', 'hill', 'see', 'fire', 'woods', '...'], tags=[1]),
#  TaggedDocument(words=["there's", 'emergency', 'evacuation', 'happening', 'building', 'across', 'street'], tags=[1]),
#  TaggedDocument(words=['afraid', 'tornado', 'coming', 'area', '...'], tags=[1]),
#  TaggedDocument(words=['three', 'people', 'died', 'heat', 'wave', 'far'], tags=[1]),
#  TaggedDocument(words=['haha', 'south', 'tampa', 'getting', 'flooded', 'hah', '-', 'wait', 'second', 'live', 'south', 'tampa', 'gonna', 'gonna', 'fvck'], tags=[1]),
#  TaggedDocument(words=['days', '.', 'lost', 'count'], tags=[1]),
#  TaggedDocument(words=['bago', 'myanmar', 'arrived', 'bago'], tags=[1]),
#  TaggedDocument(words=['damage', 'school', 'bus', 'multi', 'car', 'crash'], tags=[1]),
#  TaggedDocument(words=["what's", 'man', '?'], tags=[0]),
#  TaggedDocument(words=['love', 'fruits'], tags=[0]),
#  TaggedDocument(words=['summer', 'lovely'], tags=[0]),
#  TaggedDocument(words=['car', 'fast'], tags=[0]),
#  TaggedDocument(words=['goooooooaaaaaal', '!', '!', '!'], tags=[0]),
#  TaggedDocument(words=['ridiculous', '...'], tags=[0]),
#  TaggedDocument(words=['london', 'cool'], tags=[0]),
#  TaggedDocument(words=['love', 'skiing'], tags=[0]),
#  TaggedDocument(words=['wonderful', 'day', '!'], tags=[0]),
#  TaggedDocument(words=['looooool'], tags=[0]),
#  TaggedDocument(words=['way', '...', 'i', "can't", 'eat', 'shit'], tags=[0]),
#  TaggedDocument(words=['nyc', 'last', 'week', '!'], tags=[0]),
#  TaggedDocument(words=['love', 'girlfriend'], tags=[0]),
#  TaggedDocument(words=['cooool'], tags=[0]),
#  TaggedDocument(words=['like', 'pasta', '?'], tags=[0]),
#  TaggedDocument(words=['end', '!'], tags=[0]),
#  TaggedDocument(words=['wholesale', 'markets', 'ablaze'], tags=[1]),
#  TaggedDocument(words=['always', 'try', 'bring', 'heavy', '.'], tags=[0]),
#  TaggedDocument(words=['breaking', 'news', ':', 'nigeria', 'flag', 'set', 'ablaze', 'aba', '.'], tags=[1]),
#  TaggedDocument(words=['crying', 'more', '!', 'set', 'ablaze'], tags=[0]),
#  TaggedDocument(words=['plus', 'side', 'look', 'sky', 'last', 'night', 'ablaze'], tags=[0]),
#  TaggedDocument(words=["they've", 'built', 'much', 'hype', 'around', 'new', 'acquisitions', 'doubt', 'set', 'epl', 'ablaze', 'season', '.'], tags=[0]),
#  TaggedDocument(words=['inec', 'office', 'abia', 'set', 'ablaze'], tags=[1]),
#  TaggedDocument(words=['barbados', 'jamaica', 'two', 'cars', 'set', 'ablaze', ':', 'santa', 'cruz', 'head', 'st', 'elizabeth', 'police', 'superintende', '...'], tags=[1]),
#  TaggedDocument(words=['ablaze', 'lord'], tags=[0]),
#  TaggedDocument(words=['check', 'out', ':', 'http://t.co/roi2nsmejj', 'http://t.co/3tj8zjin21', 'http://t.co/yduixefipe'], tags=[0]),
#  TaggedDocument(words=['outside', 'ablaze', 'alive', 'dead', 'inside'], tags=[0]),
#  TaggedDocument(words=['awesome', 'time', 'visiting', 'cfc', 'head', 'office', 'ancop', 'site', 'ablaze', '.', 'thanks', 'tita', 'vida', 'taking', 'care', 'us'], tags=[0]),
#  TaggedDocument(words=['soooo', 'pumped', 'ablaze'], tags=[0]),
#  TaggedDocument(words=['wanted', 'set', 'chicago', 'ablaze', 'preaching', '...', 'hotel', '!'], tags=[0]),
#  TaggedDocument(words=['gained', 'followers', 'last', 'week', '.', 'you', '?', 'know', 'stats', 'grow'], tags=[0]),
#  TaggedDocument(words=['west', 'burned', ':', 'thousands', 'wildfires', 'ablaze', 'california', 'alone'], tags=[1]),
#  TaggedDocument(words=['building', 'perfect', 'tracklist', 'life', 'leave', 'streets', 'ablaze'], tags=[0]),
#  TaggedDocument(words=['check', 'out', ':', 'http://t.co/roi2nsmejj', 'http://t.co/3tj8zjin21', 'http://t.co/yduixefipe'], tags=[0]),
#  TaggedDocument(words=['first', 'night', 'retainers', 'in', '.', 'quite', 'weird', '.', 'better', 'get', 'used', 'it', ';', 'wear', 'every', 'single', 'night', 'next', 'year', 'least', '.'], tags=[0]),
#  TaggedDocument(words=['deputies', ':', 'man', 'shot', 'brighton', 'home', 'set', 'ablaze'], tags=[1]),
#  TaggedDocument(words=['man', 'wife', 'get', 'six', 'years', 'jail', 'setting', 'ablaze', 'niece'], tags=[1]),
#  TaggedDocument(words=['santa', 'cruz', 'head', 'st', 'elizabeth', 'police', 'superintendent', 'lanford', 'salmon', 'http://t.co/vplr5hka2u'], tags=[0]),
#  TaggedDocument(words=['police', ':', 'arsonist', 'deliberately', 'set', 'black', 'church', 'north', 'carolinaåêablaze'], tags=[1]),
#  TaggedDocument(words=['noches', 'el-bestia', 'happy', 'see', 'teammates', 'training', 'hard', 'goodnight', 'gunners', '.', '?', '?', '?'], tags=[0]),
#  TaggedDocument(words=['trampling', 'turkmen', 'flag', 'later', 'set', 'ablaze', 'others', 'vandalized', 'offices', 'turkmen', 'front'], tags=[1]),
#  TaggedDocument(words=['truck', 'ablaze', 'r21', '.', 'voortrekker', 'ave', '.', 'outside', 'tambo', 'intl', '.', 'cargo', 'section', '.'], tags=[1]),
#  TaggedDocument(words=['set', 'hearts', 'ablaze', 'every', 'city', 'gift', 'every', 'skyline', 'like', 'kiss', 'upon', 'lips'], tags=[0]),
#  TaggedDocument(words=['sky', 'ablaze', 'tonight', 'los', 'angeles', '.', 'expecting', 'ig', 'fb', 'filled', 'sunset', 'shots', 'know', 'peeps', '!', '!'], tags=[0]),
#  TaggedDocument(words=['west', 'burned', ':', 'thousands', 'wildfires', 'ablaze', 'alone', 'http://t.co/icsjgz9te1'], tags=[1]),
#  TaggedDocument(words=['revel', 'wmv', 'videos', 'means', 'mac', 'farewell', 'ablaze', 'wmv', 'en', 'route', 'dvd', ':', 'gtxrwm'], tags=[0]),
#  TaggedDocument(words=['progressive', 'greetings', '!', 'month', 'students', 'would', 'set', 'pens', 'ablaze', 'torch', 'publications', "'", '...'], tags=[0]),
#  TaggedDocument(words=['rene', 'ablaze', 'jacinta', 'secret', 'skies', 'edit', ')', 'mar'], tags=[0]),
#  TaggedDocument(words=['steve', 'fires', 'something', 'else', '!', 'california', 'tinderbox', 'clown', 'setting', 'ablaze'], tags=[1]),
#  TaggedDocument(words=['rene', 'ablaze', 'ian', 'buff', 'magnitude'], tags=[0]),
#  TaggedDocument(words=['huge', 'fire', 'wholesale', 'markets', 'ablaze'], tags=[1]),
#  TaggedDocument(words=['time', 'talk', 'go', 'until', '?', 'know', 'make', 'due', 'work', '.'], tags=[0]),
#  TaggedDocument(words=["can't", 'kids', 'cuz', 'got', 'bicycle', 'accident', 'split', 'testicles', '.', 'impossible', 'kids', "'", 'michael', 'father'], tags=[0]),
#  TaggedDocument(words=['accident', 'traffic', 'moving', 'slower', 'usual', '.'], tags=[1]),
#  TaggedDocument(words=['accident', 'center', 'lane', 'blocked', 'us', '-', '101', 'nb', 'great', 'america', 'pkwy'], tags=[1]),
#  TaggedDocument(words=['http://t.co/gkye6gjtk5', 'accident', 'summer', '?', 'read', 'advice', 'see', 'help'], tags=[0]),
#  TaggedDocument(words=['speeding', 'among', 'top', 'causes', 'teen', 'accidents', 'https://t.co/k4zomof319', 'https://t.co/s2kxvm0cba', 'car', 'accident', 'tee', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['reported', 'motor', 'vehicle', 'accident', 'curry', 'herman', 'rd', 'near', 'stephenson', 'involving', 'overturned', 'vehicle', '.', 'please', 'use', '...'], tags=[1]),
#  TaggedDocument(words=['bigrigradio', 'live', 'accident', 'awareness'], tags=[1]),
#  TaggedDocument(words=['mile', 'marker', 'south', 'mooresville', 'iredell', 'vehicle', 'accident', 'ramp', 'closed', 'pm'], tags=[1]),
#  TaggedDocument(words=['sleeping', 'pills', 'double', 'risk', 'car', 'accident'], tags=[0]),
#  TaggedDocument(words=['accident', "'", 'knew', 'gon', 'happen'], tags=[0]),
#  TaggedDocument(words=['traffic', 'accident', 'cabrillo', 'hwy', '/', 'magellan', 'av', 'mir'], tags=[1]),
#  TaggedDocument(words=['mile', 'marker', 'south', 'mooresville', 'iredell', 'vehicle', 'accident', 'congestion', 'pm'], tags=[1]),
#  TaggedDocument(words=['pastor', 'scene', 'accident', '...', 'who', 'owner', 'range', 'rover'], tags=[1]),
#  TaggedDocument(words=['mom', ':', 'get', 'home', 'fast', 'wished', "'", 'me', ':', 'that', '?', "'", 'mom', ':', 'accident', 'truck', 'spilt', 'mayonnaise'], tags=[0]),
#  TaggedDocument(words=['horrible', 'car', 'accident', 'past', 'sunday', '.', 'finally', 'able', 'get', 'around', '.', 'thank', 'god', '?', '?'], tags=[1]),
#  TaggedDocument(words=['wait', 'see', 'pissed', 'donnie', 'tell', 'another', 'accident', '?', '?'], tags=[0]),
#  TaggedDocument(words=['overturns', 'interstate', 'http://t.co/rs22lj4qfp', 'click', 'crash', '>'], tags=[1]),
#  TaggedDocument(words=['accident', 'us', 'sb', 'sr'], tags=[1]),
#  TaggedDocument(words=['carolina', 'accident', ':', 'motorcyclist', 'dies', 'crash', 'car', 'crossed', 'median', ':', 'motorcycle', 'rider', 'traveling', '...'], tags=[1]),
#  TaggedDocument(words=['fyi', 'cad', ':', 'fyi', ':', 'property', 'damage', ';', 'nhs', ';', '999', 'piner', 'rd', '/', 'horndale', 'dr'], tags=[1]),
#  TaggedDocument(words=['naayf', ':', 'first', 'accident', 'years', '.', 'turning', 'onto', 'chandanee', 'magu', 'near', 'mma', '.', 'taxi', 'rammed', 'halfway', 'turned', '.', 'everyone', 'conf', '\x89', 'û_'], tags=[1]),
#  TaggedDocument(words=['accident', 'left', 'lane', 'blocked', 'nb', 'eddy', 'rd', 'stop', 'go', 'traffic', 'back', 'nh', '-', '3a', 'delay', 'mins'], tags=[1]),
#  TaggedDocument(words=['property', 'damage', ';', 'piner', 'rd', '/', 'horndale', 'dr'], tags=[1]),
#  TaggedDocument(words=['accident'], tags=[0]),
#  TaggedDocument(words=['fyi', 'cad', ':', 'fyi', ':', 'property', 'damage', ';', 'wpd', ';', '1600', 'st'], tags=[1]),
#  TaggedDocument(words=['pm', ':', 'traffic', 'accident', 'injury', 'willis', 'foreman', 'rd'], tags=[1]),
#  TaggedDocument(words=['aashiqui', 'actress', 'anu', 'aggarwal', 'near-fatal', 'accident'], tags=[1]),
#  TaggedDocument(words=['suffield', 'alberta', 'accident'], tags=[1]),
#  TaggedDocument(words=['mile', 'backup', 'south', '...', 'accident', 'blocking', 'right', 'lanes', 'exit', 'langtree', 'rd', '...', 'consider', 'nc', 'nc', 'nc', 'alternate'], tags=[1]),
#  TaggedDocument(words=['accident', 'changed', 'life', '?', 'help', 'determine', 'options', 'financially', 'support', 'life', 'care', 'plans', 'on-going', 'treatment', '.'], tags=[0]),
#  TaggedDocument(words=['deadly', 'motorcycle', 'car', 'accident', 'happened', 'today', '.', 'details'], tags=[1]),
#  TaggedDocument(words=['marinading', 'accident', '?'], tags=[0]),
#  TaggedDocument(words=['car', 'even', 'week', 'got', 'fucking', 'car', 'accident', 'mfs', "can't", 'fucking', 'drive'], tags=[1]),
#  TaggedDocument(words=['police', 'previously', 'died', 'road', 'accident', 'killed', 'explosion'], tags=[1]),
#  TaggedDocument(words=['still', 'heard', 'church', 'leaders', 'kenya', 'coming', 'forward', 'comment', 'accident', 'issue', 'disciplinary', 'measures', '#arrestpastornganga'], tags=[0]),
#  TaggedDocument(words=['scuf', 'ps', 'live', 'game', '...', 'cya'], tags=[0]),
#  TaggedDocument(words=['man', 'drive', 'effort', 'gets', 'painful', 'man', 'win', '.', "'", 'roger', 'bannister'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/ynxnvvkcda'], tags=[0]),
#  TaggedDocument(words=['victory', 'bargain', 'basement', 'prices', '.', "'", 'dwight', 'david', 'eisenhower'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/vam5podgyw'], tags=[0]),
#  TaggedDocument(words=['remembers', 'came', 'second', '.', "'", 'charles', 'schulz'], tags=[0]),
#  TaggedDocument(words=['im', 'speaking', 'someone', 'using', 'scuf', 'xb1', 'people', 'end', 'getting', 'ps', 'also', '.'], tags=[0]),
#  TaggedDocument(words=['harder', 'conflict', 'glorious', 'triumph', '.', "'", 'thomas', 'paine'], tags=[0]),
#  TaggedDocument(words=['going', 'clay', 'pigeon', 'shooting', 'crying'], tags=[0]),
#  TaggedDocument(words=['guess', 'one', 'actually', 'wants', 'free', 'aftershock', 'tc', '...'], tags=[0]),
#  TaggedDocument(words=['aftershock', 'terrifying', 'best', 'roller', 'coaster', 'ever', 'on', '.', 'few', '.'], tags=[0]),
#  TaggedDocument(words=['aftershock'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/m4jdzmgjow'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/vam5podgyw'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/e14epzhoth'], tags=[0]),
#  TaggedDocument(words=['seeing', 'issues', 'aftershock'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/thyzomvwu0'], tags=[0]),
#  TaggedDocument(words=['icemoon', 'http://t.co/thyzomvwu0'], tags=[0]),
#  TaggedDocument(words=['bonus', 'minute', 'daily', 'habits', 'could', 'really', 'improve', 'life', '.', 'many', 'already', 'do', '?'], tags=[0]),
#  TaggedDocument(words=['aftershock', ':', 'protect', 'profit', 'next', 'global', 'financial', 'meltdown', 'david', 'wiedemer', 'http'], tags=[0]),
#  TaggedDocument(words=['moment', 'get', 'scary', 'roller', 'coaster', 'guy', 'behind', 'screaming', 'bloody', 'murder'], tags=[0]),
#  TaggedDocument(words=['aftershock', 'full', '\x89', 'ã', '¢', 'streaming', 'youtube'], tags=[0]),
#  TaggedDocument(words=['aftershock', 'protect', 'profit', 'next', 'global', 'financial', '...'], tags=[0]),
#  TaggedDocument(words=['sometimes', 'face', 'difficulties', 'something', 'wrong', 'something', 'right', '.', 'joel', 'osteen'], tags=[0]),
#  TaggedDocument(words=['thing', 'stands', 'dream', 'try', 'belief', 'actually', 'possible', '.', "'", 'joel', 'brown'], tags=[0]),
#  TaggedDocument(words=['praise', 'god', 'ministry', 'tells', 'like', 'is', '!', '!', '!'], tags=[0]),
#  TaggedDocument(words=['going', 'die', 'best', 'way', 'know', 'avoid', 'trap', 'thinking', 'something', 'lose', '.', "'", 'steve', 'jobs'], tags=[0]),
#  TaggedDocument(words=['tried', 'orange', 'aftershock', 'today', '.', 'life', 'never'], tags=[0]),
#  TaggedDocument(words=['love', 'bb'], tags=[0]),
#  TaggedDocument(words=['aftershock'], tags=[0]),
#  TaggedDocument(words=['aftershock', 'back', 'school', 'kick', 'great', '.', 'want', 'thank', 'everyone', 'making', 'possible', '.', 'great', 'night', '.'], tags=[0]),
#  TaggedDocument(words=['people', 'say', 'cannot', 'done', 'interrupt', 'it', '.', 'george', 'bernard', 'shaw'], tags=[0]),
#  TaggedDocument(words=['first', 'man', 'gets', 'oyster', 'second', 'man', 'gets', 'shell', '.', "'", 'andrew', 'carnegie'], tags=[0]),
#  TaggedDocument(words=['anyone', 'need', 'tonight', '?', 'play', 'hybrid', 'slayer', 'ps4', 'eu', '.', 'hmu'], tags=[0]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts'], tags=[1]),
#  TaggedDocument(words=['strict', 'liability', 'context', 'airplane', 'accident', ':', 'pilot', 'error', 'common', 'component', 'aviation', 'cr', '...'], tags=[1]),
#  TaggedDocument(words=['lifetime', 'odds', 'dying', 'airplane', 'accident'], tags=[0]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts', 'wedn', '...'], tags=[1]),
#  TaggedDocument(words=['awwww', "they're", 'airplane', 'accident', "they're", 'gonna', 'die', 'cuties', 'good', 'job', '!'], tags=[1]),
#  TaggedDocument(words=['family', 'members', 'osama', 'bin', 'laden', 'died', 'airplane', 'accident', 'ironic', 'mhmmm', 'gov', 'shit', 'suspect'], tags=[1]),
#  TaggedDocument(words=['man', 'goes', 'airplane', 'engine', 'accident', ':', 'http://t.co/tyjxrfd3st', 'via'], tags=[1]),
#  TaggedDocument(words=['horrible', 'accident', 'man', 'died', 'wings', 'airplane'], tags=[1]),
#  TaggedDocument(words=['cessna', 'airplane', 'accident', 'ocampo', 'coahuila', 'mexico', 'july', 'killed', 'four', 'men', 'including', 'state', 'coahuila', 'government', 'official', '.'], tags=[1]),
#  TaggedDocument(words=['man', 'died', 'wings', 'airplane'], tags=[1]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', 'http://t.co/lsmx2vwr3j', 'french', 'air', 'accident', 'experts', 'wednesday', '\x89', 'û_'], tags=[1]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts', 'wednesday', 'began', 'examining'], tags=[1]),
#  TaggedDocument(words=['mbataweel', ':', 'family', 'members', 'killed', "airplane's", 'accident'], tags=[1]),
#  TaggedDocument(words=['almost', 'sent', 'coworker', 'nudes', 'accident', 'thank', 'god', 'airplane', 'mode'], tags=[0]),
#  TaggedDocument(words=['might', 'killed', 'airplane', 'accident', 'night', 'car', 'wreck', '!', 'politics', 'best', '.'], tags=[0]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts', 'on', '...'], tags=[1]),
#  TaggedDocument(words=['unbelievably', 'insane', '.'], tags=[1]),
#  TaggedDocument(words=['horrible', 'accident', 'man', 'died', 'wings', 'airplaneåê', '(', '29-07-', '2015', ')'], tags=[1]),
#  TaggedDocument(words=['horrible', 'accident', 'man', 'died', 'wings', 'airplane'], tags=[1]),
#  TaggedDocument(words=['usama', 'bin', 'ladins', 'family', 'dead', 'airplane', 'crash', '.', 'naturally', 'accident', '.'], tags=[1]),
#  TaggedDocument(words=['pilot', 'dies', 'plane', 'crash', 'car', 'festival', 'https://t.co/kq9ae6ap2b', 'via'], tags=[1]),
#  TaggedDocument(words=['strict', 'liability', 'context', 'airplane', 'accident'], tags=[1]),
#  TaggedDocument(words=['dtn', 'brazil', ':', 'experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'exp', '...'], tags=[1]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts', 'wedn', '...'], tags=[1]),
#  TaggedDocument(words=['horrible', 'accident', 'man', 'died', 'wings', 'wtf', 'can', '\x89', 'ûªt', 'believe', 'eyes'], tags=[1]),
#  TaggedDocument(words=['nicole', 'fletcher', 'one', 'victim', 'crashed', 'airplane', 'times', 'ago', '.', 'accident', 'left', 'little', 'bit', 'trauma', 'her', '.', 'although'], tags=[1]),
#  TaggedDocument(words=['omg', 'horrible', 'accident', 'man', 'died', 'wings', 'airplane', '.'], tags=[1]),
#  TaggedDocument(words=['believe', 'this', '.', 'bro'], tags=[1]),
#  TaggedDocument(words=['experts', 'france', 'begin', 'examining', 'airplane', 'debris', 'found', 'reunion', 'island', ':', 'french', 'air', 'accident', 'experts', 'wednesday', 'began', 'examining'], tags=[1]),
#  TaggedDocument(words=['airplane', 'accident', '.'], tags=[1]),
#  TaggedDocument(words=['phone', 'looks', 'like', 'car', 'ship', 'airplane', 'accident', '.', 'terrible'], tags=[0]),
#  TaggedDocument(words=['statistically', 'risk', 'getting', 'killed', 'cop', 'dying', 'airplane', 'accident', '.'], tags=[0]),
#  TaggedDocument(words=['airplane', 'crashes', 'house', 'colombia', 'people', 'die', 'accident'], tags=[1]),
#  TaggedDocument(words=['shooting', 'airplane', 'accident'], tags=[1]),
#  TaggedDocument(words=['could', 'drone', 'cause', 'airplane', 'accident', '?', 'pilots', 'worried', 'use', 'drones', 'esp', '.', 'close', 'vicinity', 'airports'], tags=[1]),
#  TaggedDocument(words=['early', 'wake', 'call', 'sister', 'begging', 'come', 'ride', 'ambulance', 'hospital'], tags=[1]),
#  TaggedDocument(words=['http://t.co/ay6zzcupnz', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['two', 'air', 'ambulances', 'scene', 'serious', 'crash', 'two', 'cars', 'lorry', 'http://t.co/9pfeaqeski'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash', 'reuters'], tags=[1]),
#  TaggedDocument(words=['leading', 'emergency', 'services', 'boss', 'welcomes', 'new', 'ambulance', 'charity'], tags=[0]),
#  TaggedDocument(words=['anyone', 'travelling', 'aberystwyth-shrewsbury', 'right', "there's", 'incident', '.', 'services', 'halt', 'outside', 'shrews', '.', 'ambulance', 'scene', '.'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['ambulance', 'sprinter', 'automatic', 'frontline', 'vehicle', 'choice', 'lez', 'compliant', 'ebay'], tags=[0]),
#  TaggedDocument(words=['new', 'nanotech', 'device', 'able', 'target', 'destroy', 'blood', 'clots'], tags=[0]),
#  TaggedDocument(words=['hella', 'crazy', 'fights', 'ambulance', 'couple', 'mosh', 'pits'], tags=[1]),
#  TaggedDocument(words=['get', 'run', 'ambulance', 'lucky', '?'], tags=[0]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['http://t.co/7xglah10zl', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['waiting', 'ambulance'], tags=[0]),
#  TaggedDocument(words=['ok', '?', 'need', 'ambulance', '.', 'hahahah', 'good', '!'], tags=[0]),
#  TaggedDocument(words=['ambulance', 'sprinter', 'automatic', 'frontline', 'vehicle', 'choice', 'lez', 'compliant', 'ebay'], tags=[0]),
#  TaggedDocument(words=['pakistan', 'air', 'ambulance', 'helicopter', 'crash', 'kills', 'nine'], tags=[1]),
#  TaggedDocument(words=['nissan', 'ok', 'need', 'medical', 'assistance', 'call', 'ambulance', 'need'], tags=[0]),
#  TaggedDocument(words=['ems', '1', ':', 'ny', 'emts', 'petition', 'per', 'hour', 'wage', '\x89', 'ûª'], tags=[0]),
#  TaggedDocument(words=['http://t.co/fcqmkffflw', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['ambulance', 'sprinter', 'automatic', 'frontline', 'vehicle', 'choice', 'lez', 'compliant', 'ebay'], tags=[0]),
#  TaggedDocument(words=['ambulance', 'sprinter', 'automatic', 'frontline', 'vehicle', 'choice', 'lez', 'compliant', 'ebay'], tags=[0]),
#  TaggedDocument(words=['check', "what's", 'parking', 'lot', '!', '!', 'said', 'last', 'year', 'ambulance', 'st', 'johns', '.'], tags=[0]),
#  TaggedDocument(words=['know', 'way', 'ambulance', 'coming'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['http://t.co/pwwpum6rbj', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['ambulance', 'right', 'outside', 'work'], tags=[0]),
#  TaggedDocument(words=['dog', 'thinks', "he's", 'ambulance'], tags=[0]),
#  TaggedDocument(words=['happening', 'hatzolah', 'ems', 'ambulance', 'responding', 'dual', 'sirens', 'and', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['http://t.co/fuerk0gwui', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['http://t.co/x5yeuylt1x', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=["what's", 'police', 'ambulance', 'number', 'lesotho', '?', 'body', 'know', '?'], tags=[0]),
#  TaggedDocument(words=['surprised', 'still', 'cannot', 'standardised', 'clinical', 'practice', 'across', 'nhs', 'ambulance', 'trust', '.'], tags=[0]),
#  TaggedDocument(words=['http://t.co/j8tyt1xrrk', 'twelve', 'feared', 'killed', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash'], tags=[1]),
#  TaggedDocument(words=['people', 'try', 'ambulance', 'passing', '...', 'hate', 'you', '.'], tags=[0]),
#  TaggedDocument(words=['episode', 'trunks', 'annihilated', 'freiza', 'cleanest', 'shit', 'ever', '.', 'showed', 'nigga', 'mercy', '.'], tags=[0]),
#  TaggedDocument(words=['shall', 'annihilated', 'petebests', 'dessicated', 'laid', 'bare', '.', 'shall', 'kneel', 'me', '.'], tags=[0]),
#  TaggedDocument(words=['uribe', 'annihilated', 'baseball', '.'], tags=[0]),
#  TaggedDocument(words=['hey', '!', 'sundowns', 'annihilated', 'previous', 'meeting', 'celtic.indeed', 'improvement', '.'], tags=[0]),
#  TaggedDocument(words=['mizzou', 'annihilated', 'florida', 'past', 'seasons', 'even', 'ended', "muschamp's", 'career', "can't", 'compete', 'bama'], tags=[0]),
#  TaggedDocument(words=['annihilated', 'abs'], tags=[1]),
#  TaggedDocument(words=['annihilated', 'status', 'education', 'mba', 'behalf', 'easy', 'street', 'careen', ':', 'eovm'], tags=[0]),
#  TaggedDocument(words=['luka', '*', 'die', '!', 'them', '!', 'everything', 'annihilated', '!', 'alois', 'trancy'], tags=[0]),
#  TaggedDocument(words=['good', 'un', 'fella', 'sorry', 'get', 'annihilated'], tags=[0]),
#  TaggedDocument(words=['cop', 'pulls', 'drunk', 'driver', 'safety', 'seconds', 'car', 'hit', 'train', '.', 'http://t.co/thrhkhogcuåê', 'http://t.co/tzszmf2qxe', 'via'], tags=[1]),
#  TaggedDocument(words=['must', 'annihilated', '!'], tags=[0]),
#  TaggedDocument(words=['cop', 'pulls', 'drunk', 'driver', 'safety', 'seconds', 'car', 'hit', 'train', '.', 'http://t.co/c0nkgp6w03åê', 'http://t.co/imwmfdjssn', 'via'], tags=[1]),
#  TaggedDocument(words=['boom', '!', 'country', 'entirely', 'annihilated', 'britain'], tags=[0]),
#  TaggedDocument(words=['would', 'annihilated', 'might', 'well', 'thank'], tags=[0]),
#  TaggedDocument(words=['one', 'thing', 'sure-god', 'promised', 'israel', 'annihilated', '.', 'but', '...', 'the', 'horror', 'iran'], tags=[0]),
#  TaggedDocument(words=['guess', "that's", 'ok', 'armenians', 'since', "we've", 'spent', 'history', 'getting', 'annihilated'], tags=[1]),
#  TaggedDocument(words=['years', 'since', 'annihilated', 'people', 'instantly', 'became', 'aware', 'ability', 'annihilate', 'whole', 'humanity'], tags=[1]),
#  TaggedDocument(words=['day', 'tryouts', 'went', 'good', 'minus', 'fact', 'stopped', 'quickly', 'get', 'short', 'ball', 'annihilated', 'toenail', 'injury', 'even'], tags=[0]),
#  TaggedDocument(words=['oryx', 'symbol', 'arabian', 'peninsula', 'annihilated', 'hunters', '.', 'http://t.co/yangeqbuqw'], tags=[1]),
#  TaggedDocument(words=['luka', ')', 'die', '!', 'them', '!', 'everything', 'annihilated', '!', "'", 'alois', 'trancy'], tags=[0]),
#  TaggedDocument(words=['ready', 'get', 'annihilated', 'bucs', 'game'], tags=[1]),
#  TaggedDocument(words=['people', 'last', 'nights', 'weather', "'", '...', 'really', 'philip', 'thought', 'would', 'forecast', 'that', '...'], tags=[1]),
#  TaggedDocument(words=['domain', 'sophistication', 'annihilated', 'closely', 'up-to-the-minute', 'feat', ':', 'zrnf'], tags=[0]),
#  TaggedDocument(words=['seen', 'judas', 'priest', 'rob', 'came', 'back', ';', 'scorpions', 'support', '.', 'fucking', 'annihilated', 'place', '.', 'astonishing', 'gig'], tags=[0]),
#  TaggedDocument(words=['officially', 'skipping', 'hashtag', 'is', '.', 'getting', 'annihilated', 'reviews', '.', 'bummer', '.'], tags=[0]),
#  TaggedDocument(words=['thus', 'explaining', 'annihilated', '.', 'case', 'survivor', 'evolved', 'became', 'godlike'], tags=[1]),
#  TaggedDocument(words=['completely', 'annihilated', 'cech', 'paul', 'keegan', 'time', 'alive'], tags=[0]),
#  TaggedDocument(words=['annihilated', 'legion', 'itself', '.', 'survivors', 'imperfect', 'hybrid', 'project', 'quickly', 'formed', 'new', 'secret', 'cell'], tags=[0]),
#  TaggedDocument(words=['exactly', '.', "that's", 'lesnar', '/', 'cena', 'match', 'summerslam', 'last', 'year', 'great', 'brock', 'annihilated', 'guy', "who's"], tags=[0]),
#  TaggedDocument(words=['cop', 'pulls', 'drunk', 'driver', 'safety', 'seconds', 'car', 'hit', 'train', '.', 'http://t.co/f1bakpnyn6åê', 'http://t.co/lzxwoaye4x', 'via'], tags=[1]),
#  TaggedDocument(words=['annihilated', 'damascus', ':', 'syrian', 'army', 'grinds', 'gang', 'manure', 'pile'], tags=[1]),
#  TaggedDocument(words=['ok', 'completely', 'forthright', 'may', 'also', 'food', 'coma', 'bc', 'kebab', '/', 'tahini', '/', 'pickles', 'also', 'annihilated'], tags=[0]),
#  TaggedDocument(words=['fun', 'filled', 'happy-hour', 'simmons', 'bar', 'camden', 'handsome', 'one', 'got', 'annihilated', 'apart', 'game', ')'], tags=[0]),
#  TaggedDocument(words=['juanny', 'beisbol', 'sr', '.', 'annihilated', 'ball', '.'], tags=[0]),
#  TaggedDocument(words=['hell', 'fraction', 'belief', 'total', 'annihilation', 'destruction', 'usa'], tags=[1]),
#  TaggedDocument(words=['maybe', 'call', 'israel', 'tell', "we're", 'sorry', 'pres', 'sold', 'river', 'annihilation', '.'], tags=[0]),
#  TaggedDocument(words=['evildead', 'annihilation', 'civilization'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'http://t.co/6lojoorouk', 'via'], tags=[0]),
#  TaggedDocument(words=['annihilating', 'quarterstaff', 'annihilation'], tags=[1]),
#  TaggedDocument(words=['world', 'annihilation', 'vs', 'self', 'transformation', 'http://t.co/pyehwodwun', 'aliens', 'attack', 'exterminate', 'humans'], tags=[0]),
#  TaggedDocument(words=['annihilation', '::', 'http://t.co/i2hhviumtm', 'via'], tags=[1]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'https://t.co/m8mvdspjp7', 'via'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'https://t.co/sw1sbua3mn', 'via'], tags=[1]),
#  TaggedDocument(words=['please', 'sign', 'share', 'petition', 'save', 'wild', 'horses', 'arizona', '.'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'http://t.co/kpqk0c4g0m', 'via'], tags=[1]),
#  TaggedDocument(words=['please', 'check', 'salt', 'river', 'horses', 'help', 'stop', 'annihilation', 'happen', 'without', 'signatures.change', 'thx'], tags=[0]),
#  TaggedDocument(words=['souls', 'punished', 'withåêannihilation', '?', 'http://t.co/c1qxjweqqu'], tags=[0]),
#  TaggedDocument(words=['mention', 'major', 'contributor', 'annihilation', 'israel'], tags=[1]),
#  TaggedDocument(words=['need', 'help', '!', 'horses', 'die', '!', 'please', 'sign', 'petition', '!', 'take', 'stand', 'voice', 'them', '!'], tags=[1]),
#  TaggedDocument(words=['reject', 'laws', 'misguided', 'false', 'prophets', 'imprison', 'nations', 'fueling', 'self', 'annihilation'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'https://t.co/matijwkzbh', 'via'], tags=[0]),
#  TaggedDocument(words=['annihilation', 'jeb', 'christie', 'kasich', 'less', 'hours', 'away', '..', 'please', 'god', 'allow', 'least', 'one', 'full', 'day', '...'], tags=[0]),
#  TaggedDocument(words=['need', 'help-horses', 'die', '!', 'please', 'sign', 'petition', '!', 'take', 'stand', 'voice', 'them', '!'], tags=[0]),
#  TaggedDocument(words=['need', 'help', '!', 'horses', 'die', '!', 'please', 'sign', 'petition', '!', 'take', 'stand', 'voice', 'them', '!'], tags=[0]),
#  TaggedDocument(words=['hey', 'sign', 'petition', 'save', 'sing-a-long', 'order', ':'], tags=[0]),
#  TaggedDocument(words=['stop', 'annihilation', 'salt', 'river', 'wild', 'horses', '!', 'http://t.co/wvobvvtxkg', 'via'], tags=[1]),
#  TaggedDocument(words=["he's", 'current', 'nova', 'bookslast', 'checked', '..', 'he', 'tied', 'books', 'rider', 'died', 'annihilation'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'https://t.co/x2wn7o2a3w', 'via'], tags=[0]),
#  TaggedDocument(words=['please', 'sign', 'save', 'http://t.co/ikuayuseqt'], tags=[0]),
#  TaggedDocument(words=['thanks', '!', '!', '!', 'dante', '.', 'join', 'us', 'following', 'zone', '.', 'johnny', '.'], tags=[0]),
#  TaggedDocument(words=['world', 'annihilation', 'vs', 'self', 'transformation', 'http://t.co/pyehwodwun', 'aliens', 'attack', 'exterminate', 'humans'], tags=[1]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'https://t.co/0fekgyby5f', 'via'], tags=[0]),
#  TaggedDocument(words=['national', 'park', 'services', 'tonto', 'national', 'forest', ':', 'stop', 'annihilation', 'salt', 'river', 'wild', 'horse', '...', 'http://t.co/sb5r7shccj', 'via'], tags=[1]),
#  TaggedDocument(words=['gonna', 'fight', 'taylor', 'soon', 'get', 'there', '.'], tags=[0]),
#  TaggedDocument(words=['ohh', 'fukurodani', 'survive', 'apocalypse', 'bokuto', 'feels', 'horrible', 'poor', 'boy', 'ppor', 'child'], tags=[1]),
#  TaggedDocument(words=['another', 'jocelyn', 'birthday', 'apocalypse'], tags=[0]),
#  TaggedDocument(words=['rt', ':', 'janenelson', '097', ':', 'stephenscifi', ':', 'adaptation', 'watch', ':', 'charlie', "human's", 'apocalypse', 'optioned', 'film'], tags=[0]),
#  TaggedDocument(words=['apocalypse', 'please'], tags=[0]),
#  TaggedDocument(words=['another', 'hour', '!', 'august', "here's", 'red', 'rover', 'zombie', 'apocalypse'], tags=[1]),
#  TaggedDocument(words=['feel', 'like', 'pull-up', 'one', 'stages', 'apocalypse', '.'], tags=[0]),
#  TaggedDocument(words=['kinda', 'hot', 'played', 'radio', 'today', '.', "what's", 'next', '?', 'disease', 'all', '?', 'apocalypse', 'started', 'everyone', '.', 'careful', '.'], tags=[0]),
#  TaggedDocument(words=['apocalypse', 'lol', 'gf', 'm8'], tags=[0]),
#  TaggedDocument(words=['know', 'question', 'interpretation', 'sign', 'apocalypse', '.', 'called'], tags=[1]),
#  TaggedDocument(words=['julie', 'apocalypse', 'version', 'romeo', 'juliet'], tags=[0]),
#  TaggedDocument(words=['apocalypse', 'upon', 'us'], tags=[0]),
#  TaggedDocument(words=['rt', ':', 'fittscott', ':', 'minecraft', '-', 'night', 'lucky', 'block', 'mod', 'apocalypse', 'wither', 'more', '!', ')', 'mod', 'showcase', 'popularmmos', ':', 'http://t.co/mul1j9aeux', 'vi', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['begins', '..', 'day', 'one', 'snow', 'apocalypse'], tags=[1]),
#  TaggedDocument(words=['rt', ':', 'our_mother_mary', ':', 'short', 'reading', 'apocalypse', 'spirit', 'angel', 'took', 'top', 'enormous', 'high', 'mountain', 'and', '...'], tags=[0]),
#  TaggedDocument(words=['candylit', ':', 'imagine', 'sarumi', 'zombie', 'apocalypse', 'fighting', 'back', 'back', 'heart', 'heart', 'conversations', 'the', '...'], tags=[0]),
#  TaggedDocument(words=['rt', ':', 'zonewolf', '123', ':', 'liked', 'youtube', 'video', 'http://t.co/u66kyg11zd', 'minecraft', ':', 'night', 'lucky', 'block', 'mod', 'apocalypse', 'wither', 'more', '!', ')', 'mo', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=["that's", 'planet', 'lone', 'audience', 'apocalypse', '!'], tags=[0]),
#  TaggedDocument(words=['dad', 'bought', 'dvd', 'looks', 'like', 'science', 'doc', 'front', 'read', 'back', 'actually', 'impending', 'biblical', 'apocalypse'], tags=[1]),
#  TaggedDocument(words=['indeed', '.', 'apocalypse', 'comes', 'week', 'know'], tags=[0]),
#  TaggedDocument(words=['go', 'look', 'grizzly', 'peak', 'right', 'now', '...', 'looks', 'like', 'beginning', 'dystopian', 'apocalypse', 'movie'], tags=[0]),
#  TaggedDocument(words=['niece', 'asked', 'scared', 'apocalypse', 'here', '?', "'"], tags=[0]),
#  TaggedDocument(words=["there's", 'storm', 'cairo', 'latest', 'apocalypse', "'", 'set', 'photo', 'https://t.co/fs012trudg', 'via'], tags=[1]),
#  TaggedDocument(words=['minecraft', '-', 'night', 'lucky', 'block', 'mod', 'apocalypse', 'wither', 'more', '!', ')', 'mod', 'showcase', 'popularmmos', ':', 'http://t.co/tngye2fklv', 'via'], tags=[0]),
#  TaggedDocument(words=['shot', 'heart', 'xv', ':', 'going', 'totally', 'give', 'love', 'bad', 'name', 'heart', 'pierc', 'http://t.co/xpfmr368uf'], tags=[0]),
#  TaggedDocument(words=['rt', ':', 'geek_apocalypse', ':', 'gmt', 'plays', 'dark', 'souls', 'day', 'http://t.co/tngpshnl87'], tags=[0]),
#  TaggedDocument(words=['know', 'go', 'zombies', 'take', 'over', '!', '!'], tags=[0]),
#  TaggedDocument(words=['latest', 'reveals', 'queen'], tags=[1]),
#  TaggedDocument(words=['shadow', 'boxing', 'apocalypse'], tags=[1]),
#  TaggedDocument(words=['short', 'reading', 'apocalypse', 'spirit', 'angel', 'took', 'top', 'enormous', 'high', 'mountain', 'and', '...'], tags=[1]),
#  TaggedDocument(words=['enjoyed', 'live-action', 'attack', 'titan', 'every', 'time', 'see', 'posters', 'reminded', 'freshly', 'clean', 'coiffed', 'everyone', 'apocalypse', '.'], tags=[0]),
#  TaggedDocument(words=['liked', 'video', 'http://t.co/ki1ykrs9fi', 'minecraft', ':', 'night', 'lucky', 'block', 'mod', 'apocalypse', 'wither', 'more', '!', ')', 'mod', 'showcase'], tags=[0]),
#  TaggedDocument(words=['avysss', 'kill', 'flags', 'fast', 'xp', "'", 'reason'], tags=[0]),
#  TaggedDocument(words=['russaky', '89', 'kill', 'flags', 'fast', 'xp', "'", 'reason'], tags=[0]),
#  TaggedDocument(words=['vid', ')', ')', 'https://t.co/lfkmtzaekk', 'prod'], tags=[0]),
#  TaggedDocument(words=['ouvindo', 'peace', 'love', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['best', 'movie', 'ever', 'seen', '?', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['bed', 'time', '.', 'wake', 'unless', 'revolution', 'armageddon', 'start', '.'], tags=[0]),
#  TaggedDocument(words=['red', 'faction', ':', 'armageddon', 'xbox', 'full', 'read', 'ebay', 'http://t.co/ypbvs1ijya'], tags=[0]),
#  TaggedDocument(words=['already', 'know', 'shit', 'goes', '.', 'world', 'series', 'armageddon', '.'], tags=[0]),
#  TaggedDocument(words=['lith'], tags=[0]),
#  TaggedDocument(words=['gonna', 'beat', 'armageddon', 'hsu', 'hao', 'got', 'flawless', 'first', 'try'], tags=[0]),
#  TaggedDocument(words=['ben', 'affleck', '...', 'i', 'know', "there's", 'wife', '/', 'kids', 'girls', "can't", 'help', 'it', '.', 'loved', 'since', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['long', 'coat', 'hand', 'worn', 'it', '.', 'certainty', 'armageddon', 'bears', 'sense', 'occasion', '.', "'"], tags=[0]),
#  TaggedDocument(words=['phone', 'spying', 'you', '!', 'hidden', 'back', 'door', 'nsa', 'data', 'mining', 'software', 'financial', 'armageddon', 'blog'], tags=[0]),
#  TaggedDocument(words=['hyider_ghost', '2', 'kill', 'flags', 'fast', 'xp', "'", 'reason'], tags=[1]),
#  TaggedDocument(words=['lith'], tags=[0]),
#  TaggedDocument(words=['fighterdena', 'kill', 'flags', 'fast', 'xp', "'", 'reason'], tags=[0]),
#  TaggedDocument(words=['photo', ':', 'sketch', 'based', 'taste', 'armageddon', 'episode'], tags=[0]),
#  TaggedDocument(words=['armageddon'], tags=[1]),
#  TaggedDocument(words=['good', 'luck', 'tomorrow', 'night', 'get', 'coefficient', 'points', 'plz'], tags=[0]),
#  TaggedDocument(words=['armageddon'], tags=[0]),
#  TaggedDocument(words=['another', 'one', 'history', 'books', '!', 'justice', 'department', '!', ')', 'way', 'paid', 'income', 'tax'], tags=[0]),
#  TaggedDocument(words=['vladimir', 'putin', 'issues', 'major', 'warning', 'late', 'escape', 'armageddon', '?'], tags=[1]),
#  TaggedDocument(words=["god's", 'kingdom', "gov't", ')', 'rule', 'people', 'earth', 'armageddon', '.', 'http://t.co/8hgcbxukz0'], tags=[0]),
#  TaggedDocument(words=['lot', 'movies', 'die', 'hard', 'monkeys', 'armageddon', 'sixth'], tags=[0]),
#  TaggedDocument(words=['let', '\x89', 'ûªs', 'talk', 'goof', 'guild', 'saunders', '.', 'come', 'right', 'stage', '.'], tags=[0]),
#  TaggedDocument(words=['niece', 'gaining', 'ability', 'stand', '.', 'getting', 'prepared', 'toddler', 'apocalypse', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['check', 'must', 'library', 'collection', 'cd', 'http://t.co/vpqtgeqlma', 'via'], tags=[0]),
#  TaggedDocument(words=['again', '?', '?', 'eep', '!', 'thought', 'yesterday', 'saw', 'hella', 'scary', 'hail', '.'], tags=[1]),
#  TaggedDocument(words=['ahamedis', 'think', 'messiah', 'already', 'come', 'years', 'ago', '?', 'armageddon', '?', 'dajaal', '?', 'gog', 'magog', '?', '!'], tags=[0]),
#  TaggedDocument(words=['sadly', 'windows', 'reveals', "microsoft's", 'ethics', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['armageddon', 'averted', 'el', 'patron'], tags=[0]),
#  TaggedDocument(words=['time', 'hours', 'latest', 'series', 'ww1', 'blueprint', 'armageddon', 'extremely', 'impressive', '.'], tags=[0]),
#  TaggedDocument(words=['european', 'fitba', 'till', 'christmas', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['united', 'jews', 'convert', 'soon', 'die', 'armageddon', 'https://t.co/4arwwrzpsr'], tags=[0]),
#  TaggedDocument(words=['vid', ')', 'https://t.co/lfkmtzaekk', 'prod'], tags=[0]),
#  TaggedDocument(words=['tomorrow', 'day', 'start', 'armageddon'], tags=[0]),
#  TaggedDocument(words=['lee', 'comedy', ':', 'working', 'class', 'tories', 'prepare', 'armageddon', '.'], tags=[0]),
#  TaggedDocument(words=['charts', 'prove', 'financial', 'crisis', 'part', 'begun', '!', ':', 'financial', 'armageddon', 'economic', 'collapse', 'blog', 'tracks', 'tren', '...'], tags=[0]),
#  TaggedDocument(words=['paul', 'craig', 'roberts', 'vladimir', 'putin', 'issues', 'major', 'warning', 'late', 'escape'], tags=[1]),
#  TaggedDocument(words=['stage', 'now', '!', 'right', 'lights', '!', 'funny', '?', '!', 'get', 'goofballs', 'staff', 'pd', '?'], tags=[0]),
#  TaggedDocument(words=['vid', '*', '*', 'https://t.co/4i0rjc9rqu', 'comin', 'soon', '!', '!'], tags=[0]),
#  TaggedDocument(words=['well', 'done', 'celtic', 'fingers', 'crossed', 'aberdeen', 'tomorrow', 'night', '!', 'armageddon', 'eh', '...'], tags=[0]),
#  TaggedDocument(words=['beyonce', 'pick', 'http://t.co/nnmqlz91o9', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1402'], tags=[0]),
#  TaggedDocument(words=['seconds', 'summer', 'pick', 'http://t.co/j6wseptxga', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['pick', 'http://t.co/thoyhrhkfj', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['pick', 'http://t.co/thoyhrhkfj', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1411'], tags=[0]),
#  TaggedDocument(words=['seeing', 'army', 'whitewalkers', 'first', 'thing', 'slightly', 'intrigued', 'got', 'far'], tags=[0]),
#  TaggedDocument(words=['build', 'kingdom', 'lead', 'army', 'victory', '!', 'https://youtu', '.', 'start', 'friend', 'code', ':', 'lzktjnox'], tags=[0]),
#  TaggedDocument(words=['salvation', 'army', 'hosts', 'rally', 'reconnect', 'fathers', 'children', ':', 'salvation', 'army', 'hosting', 'back', 'school', 'rally', '\x89', 'û_'], tags=[1]),
#  TaggedDocument(words=['vote', 'vs', 'round'], tags=[0]),
#  TaggedDocument(words=['build', 'army', 'dogs', 'leader', 'lion', 'dogs', 'fight', 'like', 'lion', '.'], tags=[1]),
#  TaggedDocument(words=['hero', "'", ':', 'tv', 'review', 'http://t.co/kaccpk85wf'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1392'], tags=[1]),
#  TaggedDocument(words=['infantry', 'mens', 'lume', 'dial', 'army', 'analog', 'quartz', 'wrist', 'watch', 'sport', 'blue', 'nylon', 'fabric', 'full', 'rea', '\x89', 'û_', 'http://t.co/hep9k0xghb'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1441'], tags=[0]),
#  TaggedDocument(words=['victorinox', 'swiss', 'army', 'date', "women's", 'rubber', 'mop', 'watch', 'http://t.co/yfy3nkkcoh'], tags=[1]),
#  TaggedDocument(words=['drayesha', '4', ':', 'indian', 'army', 'ki', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['seconds', 'summer', 'pick', 'http://t.co/qchv3jqovk', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['beyonce', 'pick', 'http://t.co/nnmqlz91o9', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1386'], tags=[0]),
#  TaggedDocument(words=['da', 'one', 'britney', 'spears', 'lana', 'del', 'rey'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/y9wvqkgbbi', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['stony', 'jackson', "america's", 'last', 'hope', 'leads', 'army', 'felons', 'thus', 'army', 'rejects', 'army', 'satan'], tags=[0]),
#  TaggedDocument(words=['wwi', 'wwii', 'japanese', 'army', 'navy', 'military', 'japan', 'leather', 'watch', 'war', 'mido', 'ww1', 'full', 'read', 'ebay', 'http://t.co/f9j3l2yjl4'], tags=[0]),
#  TaggedDocument(words=['beyonce', 'pick', 'http://t.co/nnmqlz91o9', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['pick', 'http://t.co/thoyhrhkfj', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['beyonce', 'pick', 'http://t.co/nnmqlz91o9', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['pick', 'http://t.co/thoyhrhkfj', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['potus', 'appoints', 'brig', '.', 'gen', '.', 'richard', 'kaiser', 'member', 'mississippi', 'river', 'commission', '.', 'learn', 'mrc', ':'], tags=[0]),
#  TaggedDocument(words=['violent', 'country', 'get', 'army', 'involved', 'help', 'control', 'killings', 'bring', 'back', 'peace', 'poor', 'people', '.'], tags=[1]),
#  TaggedDocument(words=['wwi', 'wwii', 'japanese', 'army', 'navy', 'military', 'japan', 'leather', 'watch', 'war', 'mido', 'ww1', 'full', 'read', 'ebay', 'http://t.co/qumce7w2ty'], tags=[0]),
#  TaggedDocument(words=['wwi', 'wwii', 'japanese', 'army', 'navy', 'military', 'japan', 'leather', 'watch', 'war', 'mido', 'ww1', 'full', 'read', 'ebay', 'http://t.co/obfd7e4qcp'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/q2eblokeve', 'fan', 'army', 'http://t.co/encmhz6y34', 'x1434'], tags=[0]),
#  TaggedDocument(words=['one', 'direction', 'pick', 'http://t.co/imhfdaowrd', 'fan', 'army'], tags=[0]),
#  TaggedDocument(words=['two', 'jewish', 'terrorists', 'charged', 'historic-church', 'arson', 'ugly', 'truth', 'http://t.co/ieksnfsby7'], tags=[0]),
#  TaggedDocument(words=['spokane', 'authorities', 'say', "they're", 'struggling', 'solve', 'arson', 'cases', 'like', "today's", 'hamilton', '.', 'http://t.co/qbs2k01wzk'], tags=[1]),
#  TaggedDocument(words=['thousands', 'attend', 'rally', 'organized', 'peace', 'protesting', 'arson', 'attack', 'took', 'life'], tags=[1]),
#  TaggedDocument(words=['add', 'familia', 'arson', 'squad', '.'], tags=[0]),
#  TaggedDocument(words=['another', 'fake', 'hate', 'crime', 'lesbians', 'burn', 'house', 'down', '.', 'else', 'new'], tags=[1]),
#  TaggedDocument(words=['los', 'angeles', 'times', ':', 'arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'http://t.co/xwms1aww8m'], tags=[1]),
#  TaggedDocument(words=['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'grief', '\x89', 'ûª', 'israel'], tags=[1]),
#  TaggedDocument(words=['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'grief', '\x89', 'ûª', 'israel'], tags=[1]),
#  TaggedDocument(words=['sound', 'arson'], tags=[0]),
#  TaggedDocument(words=['owner', 'chicago-area', 'gay', 'bar', 'admits', 'arson', 'scheme', 'http://t.co/myhohvrhil'], tags=[0]),
#  TaggedDocument(words=['wait', 'what', '?', '?', '?', 'http://t.co/uavfrtlfs4'], tags=[0]),
#  TaggedDocument(words=['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'], tags=[1]),
#  TaggedDocument(words=['trial', 'date', 'set', 'man', 'charged', 'arson', 'burglary'], tags=[1]),
#  TaggedDocument(words=['death', 'palestinian', 'toddler', 'arson', 'attack', 'israel', 'cracks', 'jewish'], tags=[1]),
#  TaggedDocument(words=['palestinian', 'teen', 'killed', 'amid', 'protests', 'arson', 'attack'], tags=[1]),
# ...
#  TaggedDocument(words=['personal', 'favorites', 'include', 'paramore', 'muse', 'green', 'day', 'royal', 'blood'], tags=[0]),
#  TaggedDocument(words=['shed', 'innocent', 'blood', 'sons', 'daughters', 'land', 'polluted', 'psalms', 'help', 'stop', 'sin', 'abortion', '.'], tags=[0]),
#  TaggedDocument(words=['pone', 'cantar', 'crying', 'lightning', '*'], tags=[0]),
#  TaggedDocument(words=['wasnt', 'big', 'stab', 'deep', 'stab', 'theres', 'like', 'blood', 'everwhe'], tags=[1]),
#  TaggedDocument(words=['add', 'items', 'everyday', 'eating', 'habits', '.', 'please', 'research', 'take', 'blood', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['looooooooooool', 'bloody', 'hell', 'that', '?', '?'], tags=[0]),
#  TaggedDocument(words=['infected', 'bloody', 'ear', 'piercings', 'always', 'fun', '?', '?'], tags=[0]),
#  TaggedDocument(words=['aggressif', 'bloody', 'aggressive'], tags=[0]),
#  TaggedDocument(words=['entered', 'entire', 'set', 'butterlondon', 'lip', 'crayons', 'via', 'go', 'enter', '!'], tags=[0]),
#  TaggedDocument(words=['hey', 'sally', 'sorry', 'emailed', 'me', '?', 'awol', 'bloody', 'work', 'argh', '!'], tags=[0]),
#  TaggedDocument(words=['listening', 'bloody', 'jay', '.'], tags=[0]),
#  TaggedDocument(words=['forrest', 'version', "that's", 'bloody', 'awful', 'well', 'xxx'], tags=[0]),
#  TaggedDocument(words=['nightmare', 'elm', 'street', "'", 'getting', 'remade', '...'], tags=[0]),
#  TaggedDocument(words=["can't", 'bloody', 'wait', '!', '!', 'sony', 'sets', 'date', 'stephen', 'king', '\x89', 'ûªs', 'dark', 'tower', '\x89', 'ûª'], tags=[0]),
#  TaggedDocument(words=['gotta', 'try', 'let', 'go', 'many', 'bloody', 'things', '.', 'smh'], tags=[0]),
#  TaggedDocument(words=['russia', 'may', 'played', 'reason', 'link', 'bs', '.', 'okanowa', 'bloody', 'mainline', 'invasion', 'looked', 'like', 'bloody'], tags=[1]),
#  TaggedDocument(words=['bloody', 'insomnia', 'again', '!', 'grrrr', '!', '!'], tags=[1]),
#  TaggedDocument(words=['tried', 'eyes', 'akame', 'ga', 'kill', 'tokyo', 'ghoul', 'damn', 'bloody', 'dont', 'dare', 'watch', '?', '?', '?'], tags=[0]),
#  TaggedDocument(words=['suck', "that's", 'bloody', 'getting', 'means', 'amends', '.'], tags=[0]),
#  TaggedDocument(words=['call', 'weekends', '.', 'call', 'bloody', 'mary', 'times', '.', "summer's", 'full', 'them', '.', 'new', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['bloody', 'hell', 'day', '.', 'even', 'really', 'done', 'anything', '.', 'just', '.', 'tired', '.', 'everything', '.', 'thought', 'vaca', 'would', 'help', 'much', '.'], tags=[0]),
#  TaggedDocument(words=['damn', 'bloody', 'hot'], tags=[0]),
#  TaggedDocument(words=['bloody', 'sexy'], tags=[0]),
#  TaggedDocument(words=['know', 'say', 'side', 'effects', 'low', 'really', 'fast', '?', 'son', 'product', 'acne', 'cream', '..', 'side', 'effects', 'bloody', 'diarrhea', '?'], tags=[0]),
#  TaggedDocument(words=['ronda', 'rousey', 'would', 'making', 'floyd', "mayweather's", 'money', 'fights', 'bloody', 'elbow'], tags=[0]),
#  TaggedDocument(words=['awful', 'painting', '..', 'agree', 'a3', 'landscape', 'bloody', 'oils', 'paints'], tags=[0]),
#  TaggedDocument(words=['need', 'life', 'sin', 'girlfriend', 'ride', 'till', 'bloody', 'end', 'girlfriend'], tags=[0]),
#  TaggedDocument(words=['think', 'is', '.', 'well', 'bloody', 'barking'], tags=[0]),
#  TaggedDocument(words=['eh', 'hello', 'cover', 'bloody', 'thighs', 'bloody', 'cleav', '...', 'eh', 'hello', '!', 'since', 'expose', 'cleavage', 'on', '...'], tags=[0]),
#  TaggedDocument(words=['mega', 'bloody', 'marvellous'], tags=[0]),
#  TaggedDocument(words=['bloody', 'mary', 'sink', '.', 'beet', 'juice'], tags=[0]),
#  TaggedDocument(words=['monty', 'python', 'date', 'bloody', 'far', 'wants', 'go', '.'], tags=[0]),
#  TaggedDocument(words=['meet', 'bloody', 'rs5'], tags=[0]),
#  TaggedDocument(words=['friday', 'supposed', 'happy', 'day', 'bloody', 'friday', 'hah', 'zzzz'], tags=[0]),
#  TaggedDocument(words=['bloody', 'hope', 'said', 'folding', 'arms', 'sitting', 'back', 'chair', '*'], tags=[0]),
#  TaggedDocument(words=['wait', 'tell', 'college', 'friend', 'reafs', 'bloody', 'mary', 'drama', 'cd'], tags=[0]),
#  TaggedDocument(words=['came', 'kill', 'indians', '...', 'for', 'fun', "'", ':', 'video', 'smirking', 'remorseless', 'pakistani', 'killer', 'shows', 'boasting', '.'], tags=[1]),
#  TaggedDocument(words=['watched', 'episode', 's01e09', 'bloody', 'monday', '!', 'http://t.co/vrpthvpymt'], tags=[0]),
#  TaggedDocument(words=['marlon', 'williams', 'elvis', 'presley', 'marlon', 'williams', 'steel', 'panther', '.', 'shuffle', 'mode', 'like', 'bloody', 'legend', '.'], tags=[0]),
#  TaggedDocument(words=['black', 'friday', 'turns', 'bloody', 'rather', 'shopping', ')'], tags=[0]),
#  TaggedDocument(words=['someone', 'told', 'soccer', 'moms', 'getting', 'pic', 'blown', 'put', "daughter's", 'bedroom', 'walls', '.', 'not', '!', '!', '!'], tags=[0]),
#  TaggedDocument(words=['s2g', 'mentions', 'get', 'blown', 'choice', 'deactivate', 'leave', 'good', '.', 'respect', 'choices', '.'], tags=[0]),
#  TaggedDocument(words=['wow', 'wow', '!', 'club', 'blown', 'money', 'fucked', 'player', 'like', "they'd", 'pilloried', '!'], tags=[0]),
#  TaggedDocument(words=['damn', 'greinke', 'got', 'blown', 'first', 'inning'], tags=[0]),
#  TaggedDocument(words=['woke', 'blown', 'lol'], tags=[0]),
#  TaggedDocument(words=['aunt', 'marge', 'blown', 'eheks'], tags=[0]),
#  TaggedDocument(words=['yeah', 'worth', 'bc', 'already', 'many', 'spammers', 'twitter', 'probably', 'blown', 'every', 'second'], tags=[0]),
#  TaggedDocument(words=['white', 'family', 'representing', "america's", 'great', 'values', 'gets', 'blown', 'horrible', 'cgi', 'nuclear', 'strike', '...', 'lmfaoooo', '!', '!', '!'], tags=[1]),
#  TaggedDocument(words=['man', 'blown', 'up', '?', "he's", 'still', 'underground', '.'], tags=[0]),
#  TaggedDocument(words=['mentions', 'blown', 'what', '?', 'wtf', '.'], tags=[0]),
#  TaggedDocument(words=['confederate', 'ship', 'blown', 'crew', '.', 'read', 'http://t.co/iw7elszifz', 'via'], tags=[1]),
#  TaggedDocument(words=['moment', 'ur', 'win', 'mini', 'uhc', 'get', 'blown', 'creeper', 'get', 'kicked', 'flying', '...', 'salty', 'rn', '...', '!', '!', '!', '?', '?'], tags=[0]),
#  TaggedDocument(words=['get', 'approval', 'probably', "he's", 'blown'], tags=[0]),
#  TaggedDocument(words=['truckload', 'soldiers', 'blown', 'nobody', 'panics', 'one', 'little', 'lion', 'dies', 'everyone', 'loses', 'mind', "'"], tags=[1]),
#  TaggedDocument(words=['hey', 'look', '!', '!', '!', "kash's", 'foundation', 'live', 'today', 'got', 'blown', 'people', "magazine's", 'website', '!', '!', 'todd', 'blake', '...'], tags=[0]),
#  TaggedDocument(words=['got', 'last', 'month', 'went', 'ee', 'shop', '.', 'glad', 'blown', 'yet', '.'], tags=[0]),
#  TaggedDocument(words=['first', 'time', 'tweet', 'blown', 'almost', 'half', 'day', 'later', '...'], tags=[0]),
#  TaggedDocument(words=['blown', 'away', 'extension', '.', 'nothing', 'we', '\x89', 'ûªve', 'seen', 'many', 'options', 'one', '.', "'", 'https://t.co/0yzgw9zbhr'], tags=[0]),
#  TaggedDocument(words=['letting', 'stay', 'since', 'manor', 'blown', 'up', '...', 'anyways', 'buddy', '?', "'"], tags=[0]),
#  TaggedDocument(words=['loner', 'diaries', '.', 'patterns', 'sand', 'may', 'blown', 'away', '.', 'photos', 'twos', 'choked', 'flames', '...'], tags=[0]),
#  TaggedDocument(words=['even', 'though', 'bsg', 'sufficiently', 'hyped', 'years', 'somehow', 'delayed', 'watching', 'utterly', 'utterly', 'blown', 'away', '.'], tags=[1]),
#  TaggedDocument(words=["vanessa's", 'game', 'officially', 'blown', 'up', '.', 'ladies', 'gentlemen', '...', 'the', 'real', 'show', 'begin', '.'], tags=[0]),
#  TaggedDocument(words=['guaranteed', 'bitten', 'mutant', 'mosquito', 'ankle', 'blown', 'up', '.', 'little', 'cunts'], tags=[0]),
#  TaggedDocument(words=['things', 'pick', 'tozlet', 'seat', '|:', 'butt', 'leprosy', 'full-blown', 'jerkface', 'syndrome', 'lateral', 'lisp', 'toilet', 'rickets', '.'], tags=[0]),
#  TaggedDocument(words=['ig', 'blown', 'hackers', 'need', 'stop'], tags=[0]),
#  TaggedDocument(words=['whoever', 'directing', 'videos', 'needs', 'grab', 'nicki', 'minaj', 'someone', 'recognition', 'minds', 'blown', '.'], tags=[0]),
#  TaggedDocument(words=['last', 'week', 'wanted', 'sense', 'get', 'blown', 'far', 'good', '.', 'james', 'could', 'win', "he's", 'huge', 'target', 'gone', 'soon', '.'], tags=[0]),
#  TaggedDocument(words=['like', 'blown', 'amirite'], tags=[0]),
#  TaggedDocument(words=['dog', '\x89', 'ûªs', 'blown', 'kennel', 'bloody', 'yorkshire', 'terrorist'], tags=[0]),
#  TaggedDocument(words=['turn', 'espn', '2', 'get', 'blown'], tags=[0]),
#  TaggedDocument(words=['went', 'beaten', 'blown', 'up', '.', 'next', 'thing', 'know', 'ra', 'al', 'ghul', 'brought', 'back', 'life', 'escaped'], tags=[1]),
#  TaggedDocument(words=['leos', 'ass', 'got', 'metaphorically', 'blown'], tags=[0]),
#  TaggedDocument(words=['glononium', 'also', 'helps', 'blown', 'bashing', 'bottle', 'nitroglycerin', 'book', '.'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'handbag', 'women', 'cross', 'body', 'bag', 'faux', 'leather', 'fashion', 'purse', 'full', 're', '\x89', 'û_', 'http://t.co/y87gi3brlv'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'handbag', 'women', 'cross', 'body', 'bag', 'faux', 'leather', 'fashion', 'purse', 'full', 're', '\x89', 'û_', 'http://t.co/blaawhysct'], tags=[0]),
#  TaggedDocument(words=['son', 'daughter', 'would', 'like', 'see', 'going', 'war', 'iran', 'come', 'back', 'body', 'bag', '?', 'let', 'know'], tags=[0]),
#  TaggedDocument(words=['ditto', 'had', '.', 'way', 'feel', 'drank', 'vodka', 'ice', 'would', 'body', 'bag'], tags=[0]),
#  TaggedDocument(words=['handbags', 'genuine', 'mulberry', 'antony', 'cross', 'body', 'messenger', 'bag', 'dark', 'oak', 'soft', 'buffalo', 'leather', ':', 'date', ':'], tags=[0]),
#  TaggedDocument(words=['louis', 'vuitton', 'monogram', 'sophie', 'limited', 'edition', 'clutch', 'cross', 'body', 'bag', 'full', 'read', 'ebay', 'http://t.co/jrxgolnpqw'], tags=[0]),
#  TaggedDocument(words=['louis', 'vuitton', 'monogram', 'sophie', 'limited', 'edition', 'clutch', 'cross', 'body', 'bag', 'full', 'read', 'ebay', 'http://t.co/gggfvo5pb4'], tags=[0]),
#  TaggedDocument(words=['louis', 'vuitton', 'cultsierre', 'monogram', 'shoulder', 'bag', 'cross', 'body', 'bag', 'http://t.co/muf5czqjrl'], tags=[0]),
#  TaggedDocument(words=['check', 'ameribag', 'healthy', 'back', 'bag', 'shoulder', 'cross', 'body', 'backpack', 'khaki', 'tan', 'beige', 'nylon'], tags=[0]),
#  TaggedDocument(words=['photo', ':', 'bath', 'body', 'works', 'cosmetic', 'bag', 'periwinkle', 'blue', 'copper', 'piping', 'along', 'top', 'four', 'corners', '...'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'handbag', 'women', 'cross', 'body', 'bag', 'faux', 'leather', 'fashion', 'purse', 'full', 're', '\x89', 'û_', 'http://t.co/3pcntczoxv'], tags=[0]),
#  TaggedDocument(words=['new', 'summer', 'long', 'thin', 'body', 'bag', 'hip', 'word', 'skirt', 'blue', 'http://t.co/lvkoemsq8m'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/uoozxaus26', 'http://t.co/6mgbizjfgd', 'en', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['bruh', 'wanna', 'fight', 'meet', 'cage', 'bro', 'better', 'find', 'dealing', 'end', 'body', 'bag'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'handbag', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'womens', 'full', 'read', '\x89', 'û_', 'http://t.co/4fxfllrien'], tags=[0]),
#  TaggedDocument(words=['auth', 'louis', 'vuitton', 'brown', 'saumur', 'cross', 'body', 'shoulder', 'bag', 'monogram', 'full', 'read', '\x89', 'û_', 'http://t.co/hcdiwe5flc'], tags=[0]),
#  TaggedDocument(words=['check', 'vintage', 'longaberger', 'floral', 'fabric', 'shoulder', 'cross', 'body', 'bag', 'brown', 'leather', 'strap'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/zujwuiomb3'], tags=[0]),
#  TaggedDocument(words=['new', 'summer', 'long', 'thin', 'body', 'bag', 'hip', 'word', 'skirt', 'blue', 'http://t.co/8jymd9ypsj'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/uoozxaus26', 'http://t.co/pw78nbljky', 'en', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['louis', 'vuitton', 'monogram', 'sophie', 'limited', 'edition', 'clutch', 'cross', 'body', 'bag', 'full', 'read', 'ebay', 'http://t.co/i4aogcsoy5'], tags=[0]),
#  TaggedDocument(words=['new', 'women', 'handbag', 'faux', 'leather', 'ladies', 'shoulder', 'tote', 'cross', 'body', 'bag', 'large', 'satchel', 'full', 're', '\x89', 'û_', 'http://t.co/ncjpgf6znv'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/zujwuiomb3'], tags=[1]),
#  TaggedDocument(words=['one', 'day', 'heart', 'gone', 'get', 'zipped', 'body', 'bag', '.'], tags=[0]),
#  TaggedDocument(words=['http://t.co/ipxpi3me16', 'authentic', 'louis', 'vuitton', 'pochette', 'bosphore', 'shoulder', 'cross', 'body', 'bag', '\x89', 'û_'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/zujwuiomb3'], tags=[0]),
#  TaggedDocument(words=['http://t.co/hpd3snm6oy', 'vintage', 'coach', 'purse', 'camera', 'bag', 'cross', 'body', 'bids', ')'], tags=[0]),
#  TaggedDocument(words=['genuine', 'leather', 'man', 'bag', 'messenger', 'fit', 'ipad', 'mini', 'tablet', 'case', 'cross', 'body', 'air', 'jp', 'full', 'rea', '\x89', 'û_', 'http://t.co/rcburzsb2b'], tags=[0]),
#  TaggedDocument(words=['louis', 'vuitton', 'monogram', 'sophie', 'limited', 'edition', 'clutch', 'cross', 'body', 'bag', 'full', 'read', 'ebay', 'http://t.co/vjgr6liaxh'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'http://t.co/zujwuiomb3'], tags=[0]),
#  TaggedDocument(words=['nuu', 'fam', '?', '?', 'fwt', 'leave', 'body', 'bag', '?', '?'], tags=[0]),
#  TaggedDocument(words=['new', 'ladies', 'shoulder', 'tote', 'handbag', 'faux', 'leather', 'hobo', 'purse', 'cross', 'body', 'bag', 'womens', 'full', 'read', '\x89', 'û_', 'http://t.co/ur7fexszg4'], tags=[0]),
#  TaggedDocument(words=['saying', "they're", 'lucky', 'go', 'home', 'families', 'put', 'body', 'bag'], tags=[0]),
#  TaggedDocument(words=['oh', 'bagging', 'all', '!', 'body', 'bangin', "'", '.', 'saying', 'going', 'get', 'rose', '.'], tags=[0]),
#  TaggedDocument(words=['bagging', 'body', 'smoking', 'hot'], tags=[0]),
#  TaggedDocument(words=['drake', 'really', 'body', 'bagging', 'meek'], tags=[0]),
#  TaggedDocument(words=['drake', 'killing', 'dude', 'tea', 'bagging', 'dead', 'body', 'point'], tags=[1]),
#  TaggedDocument(words=['league', 'ball', 'olympic', 'level', 'body', 'bagging', 'like', 'career', 'nothing'], tags=[0]),
#  TaggedDocument(words=['idgaf', 'tough', 'canada', 'north', 'philly', 'meek', 'acting', 'like', 'bitch', 'drake', 'body', 'bagging', 'ass', 'tracks'], tags=[0]),
#  TaggedDocument(words=['body', 'bagging', 'mfs'], tags=[1]),
#  TaggedDocument(words=['skimmed', 'twitter', 'missed', 'body', 'bagging', '.'], tags=[0]),
#  TaggedDocument(words=['body', 'bagging', 'lyrically', '!'], tags=[0]),
#  TaggedDocument(words=['straight', 'body', 'bagging', '.'], tags=[0]),
#  TaggedDocument(words=['body', 'bagging', 'bitches'], tags=[0]),
#  TaggedDocument(words=['better', 'feeling', 'seeing', 'stage', 'day', 'ones', '...', 'year', 'friendships', 'still', 'body', 'bagging', 'mics', 'together', '.'], tags=[0]),
#  TaggedDocument(words=['mopheme', 'bigstar', 'johnson', 'problem', 'game', 'body', 'bagging', 'niggas'], tags=[0]),
#  TaggedDocument(words=['body', 'bagging', 'post', 'score'], tags=[0]),
#  TaggedDocument(words=['let', 'bagging', "body's", 'begin', 'lol', "ain't", 'cuffed', 'yet', 'bad', '!', '!'], tags=[0]),
#  ...]

# %%
# initialising doc2vec model weights
model = Doc2Vec(dm = 1, documents = tagged_data, vector_size = 200, min_count = 5, epochs = 50)

# save trained model
model.save('train_doc2vec.model')
# load saved model
model = Doc2Vec.load("train_doc2vec.model")

# %%
model.wv.vocab
# Out:
# {'reason': <gensim.models.keyedvectors.Vocab at 0x7fd64b7edf10>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa090>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa110>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa190>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa210>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa290>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa310>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa350>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa3d0>,
#  'residents': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa450>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa4d0>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa550>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa590>,
#  'officers': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa610>,
#  'evacuation': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa690>,
#  'shelter': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa710>,
#  'orders': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa790>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa810>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa890>,
#  'california': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa910>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fa990>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7fd64b7faa10>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x7fd64b7faa90>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fab10>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fab90>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fac10>,
#  'hwy': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fac90>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fad10>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fad90>,
#  'lake': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fae10>,
#  'county': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fae90>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x7fd64b7faf10>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x7fd64b7faf90>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd050>,
#  'flash': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd0d0>,
#  'flooding': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd150>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd1d0>,
#  'colorado': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd250>,
#  'springs': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd2d0>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd350>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd3d0>,
#  'hill': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd450>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd4d0>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd550>,
#  "there's": <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd5d0>,
#  'emergency': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd650>,
#  'happening': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd6d0>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd750>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd7d0>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd850>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd8d0>,
#  'tornado': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd950>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fd9d0>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fda50>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdad0>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdb50>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdbd0>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdc50>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdcd0>,
#  'haha': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdd50>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fddd0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fde50>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fde90>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdf10>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fd64b7fdf90>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7fd64b801050>,
#  'gonna': <gensim.models.keyedvectors.Vocab at 0x7fd64b8010d0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7fd64b801150>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7fd64b8011d0>,
#  'myanmar': <gensim.models.keyedvectors.Vocab at 0x7fd64b801250>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x7fd64b8012d0>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x7fd64b801350>,
#  'bus': <gensim.models.keyedvectors.Vocab at 0x7fd64b8013d0>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x7fd64b801450>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7fd64b8014d0>,
#  "what's": <gensim.models.keyedvectors.Vocab at 0x7fd64b801550>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7fd64b8015d0>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7fd64b801610>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7fd64b801690>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7fd64b801710>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x7fd64b801790>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7fd64b801810>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7fd64b801850>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x7fd64b8018d0>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7fd64b801950>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7fd64b8019d0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fd64b801a50>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fd64b801ad0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7fd64b801b10>,
#  "can't": <gensim.models.keyedvectors.Vocab at 0x7fd64b801b90>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x7fd64b801c10>,
#  'shit': <gensim.models.keyedvectors.Vocab at 0x7fd64b801c90>,
#  'nyc': <gensim.models.keyedvectors.Vocab at 0x7fd64b801d10>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fd64b801d90>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fd64b801e10>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x7fd64b801e90>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fd64b801f10>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fd64b801f90>,
#  'markets': <gensim.models.keyedvectors.Vocab at 0x7fd64b804050>,
#  'ablaze': <gensim.models.keyedvectors.Vocab at 0x7fd64b8040d0>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7fd64b804150>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7fd64b8041d0>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7fd64b804250>,
#  'breaking': <gensim.models.keyedvectors.Vocab at 0x7fd64b8042d0>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7fd64b804350>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7fd64b804390>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x7fd64b804410>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7fd64b804490>,
#  'aba': <gensim.models.keyedvectors.Vocab at 0x7fd64b804510>,
#  'crying': <gensim.models.keyedvectors.Vocab at 0x7fd64b804590>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fd64b804610>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7fd64b804690>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7fd64b804710>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fd64b804790>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x7fd64b804810>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fd64b804890>,
#  "they've": <gensim.models.keyedvectors.Vocab at 0x7fd64b804910>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7fd64b804990>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fd64b804a10>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fd64b804a90>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fd64b804b10>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x7fd64b804b90>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x7fd64b804c10>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7fd64b804c90>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fd64b804d10>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7fd64b804d90>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x7fd64b804e10>,
#  'cruz': <gensim.models.keyedvectors.Vocab at 0x7fd64b804e90>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7fd64b804f10>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x7fd64b804f90>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7fd64b806050>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x7fd64b8060d0>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7fd64b806150>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fd64b8061d0>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7fd64b806250>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x7fd64b8062d0>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7fd64b806350>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7fd64b8063d0>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7fd64b806450>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fd64b8064d0>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7fd64b806550>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x7fd64b8065d0>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7fd64b806650>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7fd64b8066d0>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x7fd64b806750>,
#  'chicago': <gensim.models.keyedvectors.Vocab at 0x7fd64b8067d0>,
#  'hotel': <gensim.models.keyedvectors.Vocab at 0x7fd64b806850>,
#  'gained': <gensim.models.keyedvectors.Vocab at 0x7fd64b8068d0>,
#  'followers': <gensim.models.keyedvectors.Vocab at 0x7fd64b806950>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fd64b8069d0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fd64b806a50>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7fd64b806ad0>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x7fd64b806b50>,
#  'burned': <gensim.models.keyedvectors.Vocab at 0x7fd64b806bd0>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x7fd64b806c50>,
#  'wildfires': <gensim.models.keyedvectors.Vocab at 0x7fd64b806cd0>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7fd64b806d50>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7fd64b806dd0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fd64b806e50>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7fd64b806ed0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fd64b806f50>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fd64b806fd0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7fd64b809090>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7fd64b809110>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fd64b809190>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fd64b809210>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7fd64b809290>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fd64b809310>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x7fd64b809350>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fd64b8093d0>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7fd64b809450>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fd64b8094d0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fd64b809550>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7fd64b8095d0>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7fd64b809650>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fd64b8096d0>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7fd64b809750>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fd64b8097d0>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x7fd64b809850>,
#  'arsonist': <gensim.models.keyedvectors.Vocab at 0x7fd64b8098d0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fd64b809950>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x7fd64b8099d0>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x7fd64b809a50>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7fd64b809ad0>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x7fd64b809b50>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7fd64b809bd0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7fd64b809c50>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7fd64b809cd0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7fd64b809d50>,
#  'truck': <gensim.models.keyedvectors.Vocab at 0x7fd64b809dd0>,
#  'ave': <gensim.models.keyedvectors.Vocab at 0x7fd64b809e50>,
#  'hearts': <gensim.models.keyedvectors.Vocab at 0x7fd64b809ed0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7fd64b809f50>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7fd64b809fd0>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d090>,
#  'sunset': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d110>,
#  'shots': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d190>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d210>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d290>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d310>,
#  'route': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d390>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d410>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d490>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d510>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d590>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d5d0>,
#  'steve': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d650>,
#  'fires': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d6d0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d750>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d7d0>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d850>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d8d0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d950>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fd64b80d9d0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fd64b80da50>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dad0>,
#  'cuz': <gensim.models.keyedvectors.Vocab at 0x7fd64b80db50>,
#  'accident': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dbd0>,
#  'michael': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dc50>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dcd0>,
#  'traffic': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dd50>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x7fd64b80ddd0>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7fd64b80de50>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7fd64b80ded0>,
#  'lane': <gensim.models.keyedvectors.Vocab at 0x7fd64b80df50>,
#  'blocked': <gensim.models.keyedvectors.Vocab at 0x7fd64b80dfd0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f090>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f110>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f190>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f210>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f290>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f310>,
#  'accidents': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f390>,
#  '\x89': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f3d0>,
#  'û_': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f410>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f490>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f510>,
#  'vehicle': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f590>,
#  'rd': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f610>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f690>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f710>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f790>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f810>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f890>,
#  'sleeping': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f910>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7fd64b80f990>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fa10>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fa90>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fb10>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fb50>,
#  'av': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fbd0>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fc50>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fcd0>,
#  'mom': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fd50>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fdd0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fe50>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7fd64b80fed0>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fd64b80ff50>,
#  'sunday': <gensim.models.keyedvectors.Vocab at 0x7fd64b80ffd0>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7fd64b813090>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7fd64b813110>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fd64b813190>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x7fd64b813210>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7fd64b813290>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fd64b813310>,
#  'click': <gensim.models.keyedvectors.Vocab at 0x7fd64b813390>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x7fd64b8133d0>,
#  'motorcyclist': <gensim.models.keyedvectors.Vocab at 0x7fd64b813450>,
#  'dies': <gensim.models.keyedvectors.Vocab at 0x7fd64b8134d0>,
#  'crossed': <gensim.models.keyedvectors.Vocab at 0x7fd64b813550>,
#  'motorcycle': <gensim.models.keyedvectors.Vocab at 0x7fd64b8135d0>,
#  'rider': <gensim.models.keyedvectors.Vocab at 0x7fd64b813650>,
#  'fyi': <gensim.models.keyedvectors.Vocab at 0x7fd64b8136d0>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x7fd64b813750>,
#  'dr': <gensim.models.keyedvectors.Vocab at 0x7fd64b8137d0>,
#  'onto': <gensim.models.keyedvectors.Vocab at 0x7fd64b813850>,
#  'mma': <gensim.models.keyedvectors.Vocab at 0x7fd64b8138d0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7fd64b813950>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7fd64b8139d0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7fd64b813a50>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fd64b813ad0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fd64b813b50>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x7fd64b813bd0>,
#  'blocking': <gensim.models.keyedvectors.Vocab at 0x7fd64b813c50>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fd64b813cd0>,
#  'lanes': <gensim.models.keyedvectors.Vocab at 0x7fd64b813d50>,
#  'exit': <gensim.models.keyedvectors.Vocab at 0x7fd64b813dd0>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7fd64b813e50>,
#  'nc': <gensim.models.keyedvectors.Vocab at 0x7fd64b813ed0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fd64b813f50>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7fd64b813fd0>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7fd64b816090>,
#  'deadly': <gensim.models.keyedvectors.Vocab at 0x7fd64b816110>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7fd64b816190>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fd64b816210>,
#  'details': <gensim.models.keyedvectors.Vocab at 0x7fd64b816290>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fd64b816310>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x7fd64b816390>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7fd64b816410>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x7fd64b816490>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7fd64b816510>,
#  'explosion': <gensim.models.keyedvectors.Vocab at 0x7fd64b816590>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fd64b816610>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7fd64b816690>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x7fd64b816710>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7fd64b816790>,
#  'ps': <gensim.models.keyedvectors.Vocab at 0x7fd64b816810>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7fd64b816890>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7fd64b816910>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x7fd64b816990>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x7fd64b816a10>,
#  'icemoon': <gensim.models.keyedvectors.Vocab at 0x7fd64b816a90>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x7fd64b816b10>,
#  'bargain': <gensim.models.keyedvectors.Vocab at 0x7fd64b816b90>,
#  'prices': <gensim.models.keyedvectors.Vocab at 0x7fd64b816c10>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x7fd64b816c90>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7fd64b816d10>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x7fd64b816d90>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7fd64b816e10>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fd64b816e90>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fd64b816f10>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x7fd64b816f90>,
#  'thomas': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a050>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a0d0>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a150>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a1d0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a250>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a2d0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a350>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a3d0>,
#  'aftershock': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a450>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a4d0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a550>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a5d0>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a650>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a6d0>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a750>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a7d0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a850>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a8d0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a950>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7fd64b81a9d0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fd64b81aa50>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7fd64b81aad0>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ab50>,
#  'financial': <gensim.models.keyedvectors.Vocab at 0x7fd64b81abd0>,
#  'meltdown': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ac50>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7fd64b81acd0>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ad50>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7fd64b81add0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ae50>,
#  'screaming': <gensim.models.keyedvectors.Vocab at 0x7fd64b81aed0>,
#  'bloody': <gensim.models.keyedvectors.Vocab at 0x7fd64b81af50>,
#  'murder': <gensim.models.keyedvectors.Vocab at 0x7fd64b81afd0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c090>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c110>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c190>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c210>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c290>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c310>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c390>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c410>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c490>,
#  'tells': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c510>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c590>,
#  'die': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c610>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c690>,
#  'trap': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c710>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c790>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c810>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c890>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c910>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x7fd64b81c990>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ca10>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ca90>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cb10>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cb90>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cc10>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cc90>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cd10>,
#  'george': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cd90>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ce10>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ce90>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cf10>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x7fd64b81cf90>,
#  'france': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e050>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e0d0>,
#  'examining': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e150>,
#  'airplane': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e1d0>,
#  'debris': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e250>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e2d0>,
#  'reunion': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e350>,
#  'island': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e3d0>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e450>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e4d0>,
#  'pilot': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e550>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e5d0>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e650>,
#  'dying': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e6d0>,
#  "they're": <gensim.models.keyedvectors.Vocab at 0x7fd64b81e750>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e7d0>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e850>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e8d0>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e950>,
#  'bin': <gensim.models.keyedvectors.Vocab at 0x7fd64b81e9d0>,
#  'laden': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ea50>,
#  'gov': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ead0>,
#  'suspect': <gensim.models.keyedvectors.Vocab at 0x7fd64b81eb50>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ebd0>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ec50>,
#  'wings': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ecd0>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ed50>,
#  'july': <gensim.models.keyedvectors.Vocab at 0x7fd64b81edd0>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ee50>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7fd64b81eed0>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7fd64b81ef50>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fd64b81efd0>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7fd64b823090>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x7fd64b823110>,
#  'wednesday': <gensim.models.keyedvectors.Vocab at 0x7fd64b823190>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x7fd64b823210>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7fd64b823290>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x7fd64b823310>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fd64b823390>,
#  'wreck': <gensim.models.keyedvectors.Vocab at 0x7fd64b823410>,
#  'insane': <gensim.models.keyedvectors.Vocab at 0x7fd64b823490>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7fd64b8234d0>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7fd64b823550>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7fd64b8235d0>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7fd64b823650>,
#  'exp': <gensim.models.keyedvectors.Vocab at 0x7fd64b8236d0>,
#  'wtf': <gensim.models.keyedvectors.Vocab at 0x7fd64b823750>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fd64b8237d0>,
#  'ûªt': <gensim.models.keyedvectors.Vocab at 0x7fd64b823810>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7fd64b823890>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x7fd64b823910>,
#  'victim': <gensim.models.keyedvectors.Vocab at 0x7fd64b823990>,
#  'crashed': <gensim.models.keyedvectors.Vocab at 0x7fd64b823a10>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fd64b823a90>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fd64b823b10>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fd64b823b90>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7fd64b823c10>,
#  'trauma': <gensim.models.keyedvectors.Vocab at 0x7fd64b823c90>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7fd64b823d10>,
#  'omg': <gensim.models.keyedvectors.Vocab at 0x7fd64b823d90>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fd64b823e10>,
#  'bro': <gensim.models.keyedvectors.Vocab at 0x7fd64b823e90>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7fd64b823f10>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7fd64b823f90>,
#  'ship': <gensim.models.keyedvectors.Vocab at 0x7fd64b825050>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7fd64b8250d0>,
#  'cop': <gensim.models.keyedvectors.Vocab at 0x7fd64b825150>,
#  'crashes': <gensim.models.keyedvectors.Vocab at 0x7fd64b8251d0>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7fd64b825250>,
#  'drone': <gensim.models.keyedvectors.Vocab at 0x7fd64b8252d0>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7fd64b825350>,
#  'pilots': <gensim.models.keyedvectors.Vocab at 0x7fd64b8253d0>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7fd64b825450>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7fd64b8254d0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fd64b825550>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x7fd64b8255d0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fd64b825650>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x7fd64b8256d0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fd64b825750>,
#  'ambulance': <gensim.models.keyedvectors.Vocab at 0x7fd64b8257d0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x7fd64b825850>,
#  'twelve': <gensim.models.keyedvectors.Vocab at 0x7fd64b8258d0>,
#  'feared': <gensim.models.keyedvectors.Vocab at 0x7fd64b825950>,
#  'pakistani': <gensim.models.keyedvectors.Vocab at 0x7fd64b8259d0>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x7fd64b825a50>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x7fd64b825ad0>,
#  'reuters': <gensim.models.keyedvectors.Vocab at 0x7fd64b825b50>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7fd64b825bd0>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x7fd64b825c50>,
#  'boss': <gensim.models.keyedvectors.Vocab at 0x7fd64b825cd0>,
#  'charity': <gensim.models.keyedvectors.Vocab at 0x7fd64b825d50>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7fd64b825dd0>,
#  'automatic': <gensim.models.keyedvectors.Vocab at 0x7fd64b825e50>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7fd64b825ed0>,
#  'ebay': <gensim.models.keyedvectors.Vocab at 0x7fd64b825f50>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7fd64b825fd0>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7fd64b829090>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7fd64b829110>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x7fd64b829190>,
#  'fights': <gensim.models.keyedvectors.Vocab at 0x7fd64b829210>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7fd64b829290>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7fd64b829310>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x7fd64b829390>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x7fd64b829410>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x7fd64b829490>,
#  'pakistan': <gensim.models.keyedvectors.Vocab at 0x7fd64b829510>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7fd64b829590>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x7fd64b829610>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x7fd64b829690>,
#  'ny': <gensim.models.keyedvectors.Vocab at 0x7fd64b829710>,
#  'petition': <gensim.models.keyedvectors.Vocab at 0x7fd64b829790>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7fd64b829810>,
#  'ûª': <gensim.models.keyedvectors.Vocab at 0x7fd64b829850>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7fd64b8298d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fd64b829950>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x7fd64b8299d0>,
#  "he's": <gensim.models.keyedvectors.Vocab at 0x7fd64b829a50>,
#  'sirens': <gensim.models.keyedvectors.Vocab at 0x7fd64b829ad0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fd64b829b50>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7fd64b829bd0>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7fd64b829c50>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7fd64b829cd0>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x7fd64b829d50>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x7fd64b829dd0>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7fd64b829e50>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7fd64b829ed0>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x7fd64b829f50>,
#  'annihilated': <gensim.models.keyedvectors.Vocab at 0x7fd64b829fd0>,
#  'nigga': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c090>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c110>,
#  'baseball': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c190>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c210>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c290>,
#  'florida': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c310>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c390>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c410>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c490>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c510>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c550>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c5d0>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c650>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c6d0>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c750>,
#  'pulls': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c7d0>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c850>,
#  'driver': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c8d0>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c950>,
#  'seconds': <gensim.models.keyedvectors.Vocab at 0x7fd64b82c9d0>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7fd64b82ca50>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cad0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cb50>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cbd0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cc50>,
#  'israel': <gensim.models.keyedvectors.Vocab at 0x7fd64b82ccd0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cd50>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cdd0>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7fd64b82ce50>,
#  'iran': <gensim.models.keyedvectors.Vocab at 0x7fd64b82ced0>,
#  "that's": <gensim.models.keyedvectors.Vocab at 0x7fd64b82cf50>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fd64b82cfd0>,
#  "we've": <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b090>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b110>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b190>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b210>,
#  'aware': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b290>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b310>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b390>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b410>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b490>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b510>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b590>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b610>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b690>,
#  'hunters': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b710>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b790>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b810>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b890>,
#  'forecast': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b910>,
#  'feat': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9b990>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ba10>,
#  'officially': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ba90>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bb10>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bb90>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bc10>,
#  'survivors': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bc90>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bd10>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bd90>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9be10>,
#  "who's": <gensim.models.keyedvectors.Vocab at 0x7fd64ba9be90>,
#  'syrian': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bf10>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9bf90>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e050>,
#  'pile': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e0d0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e150>,
#  'bc': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e1d0>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e250>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e2d0>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e350>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e3d0>,
#  'annihilation': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e450>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e4d0>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e550>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e5d0>,
#  "we're": <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e650>,
#  'pres': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e6d0>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e750>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e7d0>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e850>,
#  'tonto': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e8d0>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e950>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9e9d0>,
#  'horse': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ea50>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ead0>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9eb50>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ebd0>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ec50>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ecd0>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ed50>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9edd0>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ee50>,
#  'horses': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9eed0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9ef50>,
#  'thx': <gensim.models.keyedvectors.Vocab at 0x7fd64ba9efd0>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1090>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1110>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1190>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1210>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1290>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1310>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1390>,
#  'jeb': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1410>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1490>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1510>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1590>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1610>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1690>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1710>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1790>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1810>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1890>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1910>,
#  'zone': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1990>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1a10>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1a90>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1b10>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1b90>,
#  'apocalypse': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1c10>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1c90>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1d10>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1d90>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1e10>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1e90>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1f10>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fd64baa1f90>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4050>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x7fd64baa40d0>,
#  "here's": <gensim.models.keyedvectors.Vocab at 0x7fd64baa4150>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7fd64baa41d0>,
#  'zombie': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4250>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7fd64baa42d0>,
#  'kinda': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4350>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7fd64baa43d0>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4450>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7fd64baa44d0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4550>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fd64baa45d0>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4650>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x7fd64baa46d0>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4750>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7fd64baa47d0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4850>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7fd64baa48d0>,
#  'minecraft': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4950>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7fd64baa49d0>,
#  'mod': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4a50>,
#  'begins': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4ad0>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4b50>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4bd0>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4c50>,
#  'angel': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4cd0>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4d50>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4dd0>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4e50>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4ed0>,
#  'fighting': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4f50>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7fd64baa4fd0>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8090>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8110>,
#  'mo': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8190>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8210>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8290>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8310>,
#  'indeed': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8390>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8410>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8490>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8510>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8590>,
#  'scared': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8610>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8690>,
#  'storm': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8710>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8790>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8810>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8890>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8910>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8990>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8a10>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8a90>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8b10>,
#  'shadow': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8b90>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8c10>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8c90>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8d10>,
#  'armageddon': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8d90>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8e10>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8e90>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8f10>,
#  'xbox': <gensim.models.keyedvectors.Vocab at 0x7fd64baa8f90>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa050>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa0d0>,
#  'ben': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa150>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa1d0>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa250>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa2d0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa350>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa3d0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa450>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa4d0>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa550>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa5d0>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa610>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa690>,
#  'taste': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa710>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa790>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa810>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa890>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa910>,
#  'tax': <gensim.models.keyedvectors.Vocab at 0x7fd64baaa990>,
#  'putin': <gensim.models.keyedvectors.Vocab at 0x7fd64baaaa10>,
#  'warning': <gensim.models.keyedvectors.Vocab at 0x7fd64baaaa90>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7fd64baaab10>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x7fd64baaab90>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7fd64baaac10>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7fd64baaac90>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7fd64baaad10>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fd64baaad90>,
#  'ûªs': <gensim.models.keyedvectors.Vocab at 0x7fd64baaadd0>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7fd64baaae50>,
#  'prepared': <gensim.models.keyedvectors.Vocab at 0x7fd64baaaed0>,
#  'toddler': <gensim.models.keyedvectors.Vocab at 0x7fd64baaaf50>,
#  'library': <gensim.models.keyedvectors.Vocab at 0x7fd64baaafd0>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x7fd64baae090>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7fd64baae110>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fd64baae190>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7fd64baae210>,
#  'hail': <gensim.models.keyedvectors.Vocab at 0x7fd64baae290>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fd64baae310>,
#  'sadly': <gensim.models.keyedvectors.Vocab at 0x7fd64baae390>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x7fd64baae410>,
#  'averted': <gensim.models.keyedvectors.Vocab at 0x7fd64baae490>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7fd64baae510>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7fd64baae590>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x7fd64baae610>,
# ...
#  'part': <gensim.models.keyedvectors.Vocab at 0x7fd64baae990>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7fd64baaea10>,
#  'collapse': <gensim.models.keyedvectors.Vocab at 0x7fd64baaea90>,
#  'tracks': <gensim.models.keyedvectors.Vocab at 0x7fd64baaeb10>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x7fd64baaeb90>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7fd64baaec10>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x7fd64baaec90>,
#  'fingers': <gensim.models.keyedvectors.Vocab at 0x7fd64baaed10>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x7fd64baaed90>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x7fd64baaee10>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7fd64baaee90>,
#  'http://t.co/q2eblokeve': <gensim.models.keyedvectors.Vocab at 0x7fd64baaeed0>,
#  'http://t.co/encmhz6y34': <gensim.models.keyedvectors.Vocab at 0x7fd64baaef10>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x7fd64baaef90>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1050>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7fd64bab10d0>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1150>,
#  'rally': <gensim.models.keyedvectors.Vocab at 0x7fd64bab11d0>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1250>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7fd64bab12d0>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1350>,
#  'dogs': <gensim.models.keyedvectors.Vocab at 0x7fd64bab13d0>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1450>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x7fd64bab14d0>,
#  'hero': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1550>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7fd64bab15d0>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1650>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x7fd64bab16d0>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1750>,
#  'rea': <gensim.models.keyedvectors.Vocab at 0x7fd64bab17d0>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1850>,
#  'rubber': <gensim.models.keyedvectors.Vocab at 0x7fd64bab18d0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1950>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x7fd64bab19d0>,
#  'jackson': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1a50>,
#  "america's": <gensim.models.keyedvectors.Vocab at 0x7fd64bab1ad0>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1b50>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1bd0>,
#  'wwii': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1c50>,
#  'japanese': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1cd0>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1d50>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1dd0>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1e50>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1ed0>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1f50>,
#  'mido': <gensim.models.keyedvectors.Vocab at 0x7fd64bab1fd0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4090>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4110>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4190>,
#  'jewish': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4210>,
#  'terrorists': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4290>,
#  'charged': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4310>,
#  'arson': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4390>,
#  'ugly': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4410>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4490>,
#  'authorities': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4510>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4590>,
#  "today's": <gensim.models.keyedvectors.Vocab at 0x7fd64bab4610>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4690>,
#  'squad': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4710>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4790>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4810>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4890>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4910>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4990>,
#  'caught': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4a10>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4a90>,
#  'mourning': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4b10>,
#  'notices': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4b90>,
#  'stabbing': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4c10>,
#  'victims': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4c90>,
#  'stir': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4d10>,
#  'grief': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4d90>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4e10>,
#  'chicago-area': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4e90>,
#  'gay': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4f10>,
#  'admits': <gensim.models.keyedvectors.Vocab at 0x7fd64bab4f90>,
#  'scheme': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7050>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7fd64bab70d0>,
#  'trial': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7150>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7fd64bab71d0>,
#  'palestinian': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7250>,
#  'amid': <gensim.models.keyedvectors.Vocab at 0x7fd64bab72d0>,
#  'hunt': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7350>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x7fd64bab73d0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7450>,
#  'tennessee': <gensim.models.keyedvectors.Vocab at 0x7fd64bab74d0>,
#  'destroyed': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7550>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fd64bab75d0>,
#  'alleged': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7650>,
#  'east': <gensim.models.keyedvectors.Vocab at 0x7fd64bab76d0>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7750>,
#  'serial': <gensim.models.keyedvectors.Vocab at 0x7fd64bab77d0>,
#  'arrested': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7850>,
#  'suspected': <gensim.models.keyedvectors.Vocab at 0x7fd64bab78d0>,
#  'calif': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7950>,
#  'legal': <gensim.models.keyedvectors.Vocab at 0x7fd64bab79d0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7a50>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7ad0>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7b50>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7bd0>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7c50>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7cd0>,
#  'captures': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7d50>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7dd0>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7e50>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7ed0>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7f50>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fd64bab7fd0>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7fd64babb090>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x7fd64babb110>,
#  'salem': <gensim.models.keyedvectors.Vocab at 0x7fd64babb190>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7fd64babb210>,
#  'blamed': <gensim.models.keyedvectors.Vocab at 0x7fd64babb290>,
#  'blaze': <gensim.models.keyedvectors.Vocab at 0x7fd64babb310>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7fd64babb390>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7fd64babb410>,
#  'lmfao': <gensim.models.keyedvectors.Vocab at 0x7fd64babb490>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x7fd64babb510>,
#  'moves': <gensim.models.keyedvectors.Vocab at 0x7fd64babb590>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x7fd64babb610>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7fd64babb690>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7fd64babb710>,
#  'court': <gensim.models.keyedvectors.Vocab at 0x7fd64babb790>,
#  'lmao': <gensim.models.keyedvectors.Vocab at 0x7fd64babb810>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7fd64babb890>,
#  'hiring': <gensim.models.keyedvectors.Vocab at 0x7fd64babb910>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fd64babb990>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x7fd64babba10>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7fd64babba90>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7fd64babbb10>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7fd64babbb90>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x7fd64babbc10>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7fd64babbc90>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x7fd64babbd10>,
#  'nashville': <gensim.models.keyedvectors.Vocab at 0x7fd64babbd90>,
#  'theater': <gensim.models.keyedvectors.Vocab at 0x7fd64babbe10>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x7fd64babbe90>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x7fd64babbf10>,
#  'û': <gensim.models.keyedvectors.Vocab at 0x7fd64babbf50>,
#  '\x9d': <gensim.models.keyedvectors.Vocab at 0x7fd64babbf90>,
#  'terror': <gensim.models.keyedvectors.Vocab at 0x7fd64babd050>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7fd64babd0d0>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7fd64babd150>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7fd64babd1d0>,
#  'warnings': <gensim.models.keyedvectors.Vocab at 0x7fd64babd250>,
#  'claims': <gensim.models.keyedvectors.Vocab at 0x7fd64babd2d0>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7fd64babd350>,
#  'bombing': <gensim.models.keyedvectors.Vocab at 0x7fd64babd3d0>,
#  'saudi': <gensim.models.keyedvectors.Vocab at 0x7fd64babd450>,
#  'mosque': <gensim.models.keyedvectors.Vocab at 0x7fd64babd4d0>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7fd64babd550>,
#  'feminists': <gensim.models.keyedvectors.Vocab at 0x7fd64babd5d0>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7fd64babd650>,
#  'militants': <gensim.models.keyedvectors.Vocab at 0x7fd64babd6d0>,
#  'udhampur': <gensim.models.keyedvectors.Vocab at 0x7fd64babd750>,
#  'spos': <gensim.models.keyedvectors.Vocab at 0x7fd64babd7d0>,
#  'injured': <gensim.models.keyedvectors.Vocab at 0x7fd64babd850>,
#  'obama': <gensim.models.keyedvectors.Vocab at 0x7fd64babd8d0>,
#  'officials': <gensim.models.keyedvectors.Vocab at 0x7fd64babd950>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x7fd64babd9d0>,
#  'terrorist': <gensim.models.keyedvectors.Vocab at 0x7fd64babda50>,
#  'weapon': <gensim.models.keyedvectors.Vocab at 0x7fd64babdad0>,
#  'texas': <gensim.models.keyedvectors.Vocab at 0x7fd64babdb50>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7fd64babdbd0>,
#  'israeli': <gensim.models.keyedvectors.Vocab at 0x7fd64babdc50>,
#  'forces': <gensim.models.keyedvectors.Vocab at 0x7fd64babdcd0>,
#  'raid': <gensim.models.keyedvectors.Vocab at 0x7fd64babdd50>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x7fd64babddd0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7fd64babde50>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7fd64babded0>,
#  'senior': <gensim.models.keyedvectors.Vocab at 0x7fd64babdf50>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x7fd64babdfd0>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0090>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0110>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0190>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0210>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0290>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0310>,
#  'theatre': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0390>,
#  'homeless': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0410>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0490>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0510>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0590>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0610>,
#  'released': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0690>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0710>,
#  'maria': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0790>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0810>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0890>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0910>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0990>,
#  'atomic': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0a10>,
#  'bombs': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0a90>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0b10>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0b90>,
#  'gop': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0c10>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0c90>,
#  'yay': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0d10>,
#  'attacked': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0d90>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0e10>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0e90>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0f10>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7fd64bac0f90>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3050>,
#  'civilians': <gensim.models.keyedvectors.Vocab at 0x7fd64bac30d0>,
#  'gaza': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3150>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x7fd64bac31d0>,
#  'muslims': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3250>,
#  'temple': <gensim.models.keyedvectors.Vocab at 0x7fd64bac32d0>,
#  'mount': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3350>,
#  'waving': <gensim.models.keyedvectors.Vocab at 0x7fd64bac33d0>,
#  'pamela': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3450>,
#  'geller': <gensim.models.keyedvectors.Vocab at 0x7fd64bac34d0>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3550>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x7fd64bac35d0>,
#  'youth': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3650>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7fd64bac36d0>,
#  'patrick': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3750>,
#  'literally': <gensim.models.keyedvectors.Vocab at 0x7fd64bac37d0>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3850>,
#  'abuse': <gensim.models.keyedvectors.Vocab at 0x7fd64bac38d0>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3950>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7fd64bac39d0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3a50>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3ad0>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3b50>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3bd0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3c50>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3cd0>,
#  'tweets': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3d50>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3dd0>,
#  'flew': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3e50>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3ed0>,
#  'fukushima': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3f50>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7fd64bac3fd0>,
#  'avalanche': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7090>,
#  'defense': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7110>,
#  'louis': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7190>,
#  'row': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7210>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7290>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7310>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7390>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7410>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7490>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7510>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fd64bac7590>,
#  ...}

# %%
model.corpus_total_words
# Out:
# 72070

# %%
# the model weights are already initialised.
# Paragraph Vector Distributed memory acts as a memory that remembers what is missing from the 
# current context.
# %timeit
for epoch in range(30):
    model.train(tagged_data, total_examples = len(tagged_data), epochs=1)
    model.alpha -=0.002
    model.min_alpha = model.alpha

# %%
tagged_data[1000].tags[0]
# Out:
# 0

# %%
vector = model.infer_vector(['leagues', 'ball', 'olympic', 'level', 'body', 'bagging', 'like', 'career', 'nothing'])

# %%
vector.shape
# Out:
# (200,)

# %%
def vectors_Doc2vec(model, tagged_docs):
    sents = tagged_docs
    tags, vectors = zip(*[(doc.tags[0], model.infer_vector(doc.words)) for doc in sents])
    return tags, vectors

# %%
targets, vectors = vectors_Doc2vec(model, tagged_data)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(C = 0.1, n_jobs=1)

log_reg.fit(vectors, targets)
y_pred = log_reg.predict(vectors)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(target, y_pred)
# Out:
# 0.6628136083015894

# %%
y_pred[1000]
# Out:
# 0

# %%
set(y_pred)
# Out:
# {0, 1}
